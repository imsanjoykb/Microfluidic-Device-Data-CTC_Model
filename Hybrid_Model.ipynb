# %% [markdown]
# ### Hybrid Model: CNN + LSTM

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf  # Import TensorFlow
from sklearn.metrics import roc_curve, auc
from sklearn.model_selection import train_test_split 
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv1D, MaxPooling1D, GlobalAveragePooling1D, Dense, LSTM, concatenate, Dropout
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical

def load_data(directory, cell_type):
    position_data = []
    velocity_data = []
    labels = []
    for filename in os.listdir(directory):
        if filename.endswith('.csv'):
            df = pd.read_csv(os.path.join(directory, filename))
            position = df[['X', 'Y', 'Z']].values
            velocity = df[['velocity_x', 'velocity_y', 'velocity_z']].values
            position_data.append(position)
            velocity_data.append(velocity)
            labels.append(cell_type)
    return position_data, velocity_data, labels

# Load PLT and WBC data
soft_position, soft_velocity, soft_labels = load_data('D:/Assessment/PINN/LSTM-Problem/NewTimeSeriesDataForCells/soft_dir', 0)
rigid_position, rigid_velocity, rigid_labels = load_data('D:/Assessment/PINN/LSTM-Problem/NewTimeSeriesDataForCells/hard_dir', 1)

# Combine data and labels
all_position_data = soft_position + rigid_position
all_velocity_data = soft_velocity + rigid_velocity
all_labels = soft_labels + rigid_labels

# Pad sequences to the same length
max_length = max(max(len(seq) for seq in all_position_data), max(len(seq) for seq in all_velocity_data))
padded_position_data = pad_sequences(all_position_data, maxlen=max_length, dtype='float32', padding='post', truncating='post')
padded_velocity_data = pad_sequences(all_velocity_data, maxlen=max_length, dtype='float32', padding='post', truncating='post')

# Normalize the data
position_scaler = StandardScaler()
velocity_scaler = StandardScaler()

normalized_position_data = np.array([position_scaler.fit_transform(seq) for seq in padded_position_data])
normalized_velocity_data = np.array([velocity_scaler.fit_transform(seq) for seq in padded_velocity_data])

# Convert labels to categorical
labels = to_categorical(all_labels)

# Split the data into training and testing sets
X_pos_train, X_pos_test, X_vel_train, X_vel_test, y_train, y_test = train_test_split(
    normalized_position_data, normalized_velocity_data, labels, test_size=0.2, random_state=42)

def create_hybrid_model(input_shape):
    # Separate inputs for position and velocity
    position_input = Input(shape=input_shape)
    velocity_input = Input(shape=input_shape)

    # Convolutions for position
    x_pos = Conv1D(64, kernel_size=3, activation='relu')(position_input)
    x_pos = MaxPooling1D(2)(x_pos)
    x_pos = Conv1D(64, kernel_size=3, activation='relu')(x_pos)
    x_pos = LSTM(64, return_sequences=True)(x_pos)
    x_pos = GlobalAveragePooling1D()(x_pos)

    # Convolutions for velocity
    x_vel = Conv1D(64, kernel_size=3, activation='relu')(velocity_input)
    x_vel = MaxPooling1D(2)(x_vel)
    x_vel = Conv1D(64, kernel_size=3, activation='relu')(x_vel)
    x_vel = LSTM(64, return_sequences=True)(x_vel)
    x_vel = GlobalAveragePooling1D()(x_vel)

    # Combine features
    combined = concatenate([x_pos, x_vel])

    # Dense layers
    x = Dense(128, activation='relu')(combined)
    x = Dropout(0.5)(x)
    x = Dense(64, activation='relu')(x)
    output = Dense(2, activation='softmax')(x)

    # Create model
    model = Model(inputs=[position_input, velocity_input], outputs=output)
    return model

def create_all_outputs_model(model):
    return Model(inputs=model.inputs, outputs=[layer.output for layer in model.layers])

input_shape = (max_length, 3)  # 3 features for both position and velocity
model = create_hybrid_model(input_shape)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Print model summary
model.summary()

# Custom callback to track test accuracy
class TestAccuracyCallback(tf.keras.callbacks.Callback):
    def __init__(self, test_data):
        self.test_data = test_data
        self.test_accuracies = []

    def on_epoch_end(self, epoch, logs=None):
        X_pos_test, X_vel_test, y_test = self.test_data
        test_loss, test_accuracy = self.model.evaluate([X_pos_test, X_vel_test], y_test, verbose=0)
        self.test_accuracies.append(test_accuracy)
        print(f'\nTest accuracy at epoch {epoch+1}: {test_accuracy:.4f}')

# Instantiate the callback
test_accuracy_callback = TestAccuracyCallback((X_pos_test, X_vel_test, y_test))

# Train the model with the custom callback included
cnn_history = model.fit(
    [X_pos_train, X_vel_train], y_train,
    epochs=120,
    batch_size=32,
    validation_split=0.2,
    verbose=1,
    callbacks=[test_accuracy_callback]
)

all_outputs_model = create_all_outputs_model(model)

# Evaluate the model
test_loss, test_accuracy = model.evaluate([X_pos_test, X_vel_test], y_test, verbose=0)
print(f"Test accuracy: {test_accuracy:.4f}")

# Plot for Training, Validation, and Test Accuracy
plt.figure(figsize=(7, 6))

# Apply seaborn style and color palette
sns.set(style="whitegrid")
colors = sns.color_palette("muted")

plt.plot(cnn_history.history['accuracy'], label='Training Accuracy', color=colors[0], linestyle='--', linewidth=2, marker='o', markersize=5)
plt.plot(cnn_history.history['val_accuracy'], label='Validation Accuracy', color=colors[1], linestyle='--', linewidth=2, marker='s', markersize=5)
plt.plot(test_accuracy_callback.test_accuracies, label='Test Accuracy', color='green', linestyle='--', linewidth=2, marker='^', markersize=5)

plt.title('Accuracy Curve CNN+LSTM', fontsize=16, fontweight='bold')
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Accuracy', fontsize=14)
plt.legend(fontsize=12, shadow=True)
plt.grid(True, linestyle='--', alpha=0.6)

plt.tight_layout()
plt.show()

sample_pos = X_pos_test[:1]
sample_vel = X_vel_test[:1]

all_layer_outputs = all_outputs_model.predict([sample_pos, sample_vel])

# Prediction for a sample
def predict_cell_type(trajectory):
    new_position = new_trajectory[:, :3]
    new_velocity = new_trajectory[:, 3:]
    padded_position = pad_sequences([new_position], maxlen=max_length, dtype='float32', padding='post', truncating='post')
    padded_velocity = pad_sequences([new_velocity], maxlen=max_length, dtype='float32', padding='post', truncating='post')
    normalized_position = position_scaler.transform(padded_position[0])
    normalized_velocity = velocity_scaler.transform(padded_velocity[0])
    position_trajectory = normalized_position.reshape(1, max_length, 3)
    velocity_trajectory = normalized_velocity.reshape(1, max_length, 3)
    prediction = model.predict([position_trajectory, velocity_trajectory])
    cell_type = "soft" if prediction[0][0] > prediction[0][1] else "rigid"
    return cell_type, prediction[0][0], prediction[0][1]

example_csv_path = 'D:/Assessment/PINN/LSTM-Problem/NewTimeSeriesDataForCells/hard_dir/output_0.0 (1)_split_1.csv'
new_trajectory = pd.read_csv(example_csv_path)[['X', 'Y', 'Z','velocity_x', 'velocity_y', 'velocity_z']].values
predicted_cell_type_1 = predict_cell_type(new_trajectory)
print(f"Predicted cell type: {predicted_cell_type_1}")

# Apply seaborn style and color palette
sns.set(style="whitegrid")
colors = sns.color_palette("muted")

# Compute ROC curve and ROC area for the model
y_pred = model.predict([X_pos_test, X_vel_test])
fpr, tpr, _ = roc_curve(y_test[:, 1], y_pred[:, 1])
roc_auc = auc(fpr, tpr)

# Plot for ROC curve
plt.figure(figsize=(7, 6))

plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})', marker='o', markersize=5)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=14)
plt.ylabel('True Positive Rate', fontsize=14)
plt.title('Receiver Operating Characteristic (ROC) Curve (CNN+LSTM)', fontsize=16, fontweight='bold')
plt.legend(loc="lower right", fontsize=12, shadow=True)
plt.grid(True, linestyle='--', alpha=0.6)

plt.tight_layout()
plt.show()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 431, 3)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_3       │ (None, 431, 3)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_4 (Conv1D)   │ (None, 429, 64)   │        640 │ input_layer_2[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_6 (Conv1D)   │ (None, 429, 64)   │        640 │ input_layer_3[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_2     │ (None, 214, 64)   │          0 │ conv1d_4[0][0]    │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_3     │ (None, 214, 64)   │          0 │ conv1d_6[0][0]    │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_5 (Conv1D)   │ (None, 212, 64)   │     12,352 │ max_pooling1d_2[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_7 (Conv1D)   │ (None, 212, 64)   │     12,352 │ max_pooling1d_3[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_2 (LSTM)       │ (None, 212, 64)   │     33,024 │ conv1d_5[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_3 (LSTM)       │ (None, 212, 64)   │     33,024 │ conv1d_7[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 64)        │          0 │ lstm_2[0][0]      │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 64)        │          0 │ lstm_3[0][0]      │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 128)       │          0 │ global_average_p… │
# │ (Concatenate)       │                   │            │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 128)       │     16,512 │ concatenate_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 128)       │          0 │ dense_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 64)        │      8,256 │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 2)         │        130 │ dense_4[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 116,930 (456.76 KB)
#  Trainable params: 116,930 (456.76 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.5078 - loss: 0.6942
# Test accuracy at epoch 1: 0.5763
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 129ms/step - accuracy: 0.5105 - loss: 0.6938 - val_accuracy: 0.5368 - val_loss: 0.6971
# Epoch 2/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.5589 - loss: 0.6815
# Test accuracy at epoch 2: 0.5763
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step - accuracy: 0.5585 - loss: 0.6819 - val_accuracy: 0.5368 - val_loss: 0.6908
# Epoch 3/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.5515 - loss: 0.6865
# Test accuracy at epoch 3: 0.5763
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - accuracy: 0.5517 - loss: 0.6863 - val_accuracy: 0.5368 - val_loss: 0.6931
# Epoch 4/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.5583 - loss: 0.6833
# Test accuracy at epoch 4: 0.5763
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step - accuracy: 0.5586 - loss: 0.6832 - val_accuracy: 0.5263 - val_loss: 0.6927
# Epoch 5/120
# 11/12 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.5868 - loss: 0.6797
# Test accuracy at epoch 5: 0.6017
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - accuracy: 0.5835 - loss: 0.6800 - val_accuracy: 0.5263 - val_loss: 0.6941
# Epoch 6/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.5098 - loss: 0.6897
# Test accuracy at epoch 6: 0.5763
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - accuracy: 0.5132 - loss: 0.6892 - val_accuracy: 0.5368 - val_loss: 0.7408
# Epoch 7/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.5693 - loss: 0.6936
# Test accuracy at epoch 7: 0.6271
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - accuracy: 0.5710 - loss: 0.6927 - val_accuracy: 0.5263 - val_loss: 0.6921
# Epoch 8/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.6204 - loss: 0.6726
# Test accuracy at epoch 8: 0.6102
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - accuracy: 0.6198 - loss: 0.6723 - val_accuracy: 0.5684 - val_loss: 0.6978
# Epoch 9/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.6234 - loss: 0.6676
# Test accuracy at epoch 9: 0.6356
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - accuracy: 0.6232 - loss: 0.6680 - val_accuracy: 0.5579 - val_loss: 0.7154
# Epoch 10/120
# 11/12 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.6249 - loss: 0.6597
# Test accuracy at epoch 10: 0.6102
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - accuracy: 0.6231 - loss: 0.6604 - val_accuracy: 0.5579 - val_loss: 0.6946
# Epoch 11/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.6070 - loss: 0.6609
# Test accuracy at epoch 11: 0.6271
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step - accuracy: 0.6070 - loss: 0.6607 - val_accuracy: 0.5579 - val_loss: 0.6904
# Epoch 12/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.6349 - loss: 0.6507
# Test accuracy at epoch 12: 0.5932
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - accuracy: 0.6336 - loss: 0.6529 - val_accuracy: 0.5368 - val_loss: 0.7924
# Epoch 13/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.6536 - loss: 0.6377
# Test accuracy at epoch 13: 0.6017
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - accuracy: 0.6494 - loss: 0.6400 - val_accuracy: 0.5579 - val_loss: 0.6920
# Epoch 14/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.6022 - loss: 0.6713
# Test accuracy at epoch 14: 0.6102
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - accuracy: 0.6030 - loss: 0.6713 - val_accuracy: 0.5579 - val_loss: 0.6944
# Epoch 15/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.6091 - loss: 0.6658
# Test accuracy at epoch 15: 0.6102
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step - accuracy: 0.6092 - loss: 0.6660 - val_accuracy: 0.5579 - val_loss: 0.6986
# Epoch 16/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.6446 - loss: 0.6484
# Test accuracy at epoch 16: 0.6186
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - accuracy: 0.6428 - loss: 0.6493 - val_accuracy: 0.5579 - val_loss: 0.7042
# Epoch 17/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.6189 - loss: 0.6644
# Test accuracy at epoch 17: 0.6102
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - accuracy: 0.6193 - loss: 0.6640 - val_accuracy: 0.5474 - val_loss: 0.6945
# Epoch 18/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.6286 - loss: 0.6536
# Test accuracy at epoch 18: 0.6271
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - accuracy: 0.6280 - loss: 0.6537 - val_accuracy: 0.5579 - val_loss: 0.6982
# Epoch 19/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.6408 - loss: 0.6455
# Test accuracy at epoch 19: 0.6102
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.6383 - loss: 0.6463 - val_accuracy: 0.5579 - val_loss: 0.6996
# Epoch 20/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.6297 - loss: 0.6369
# Test accuracy at epoch 20: 0.6186
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - accuracy: 0.6306 - loss: 0.6373 - val_accuracy: 0.5579 - val_loss: 0.6940
# Epoch 21/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.6382 - loss: 0.6408
# Test accuracy at epoch 21: 0.6356
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.6380 - loss: 0.6416 - val_accuracy: 0.5684 - val_loss: 0.6878
# Epoch 22/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.6431 - loss: 0.6322
# Test accuracy at epoch 22: 0.6271
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - accuracy: 0.6430 - loss: 0.6323 - val_accuracy: 0.5474 - val_loss: 0.6884
# Epoch 23/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.6740 - loss: 0.6008
# Test accuracy at epoch 23: 0.6102
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - accuracy: 0.6726 - loss: 0.6025 - val_accuracy: 0.5895 - val_loss: 0.7025
# Epoch 24/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.6539 - loss: 0.6428
# Test accuracy at epoch 24: 0.6102
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - accuracy: 0.6534 - loss: 0.6432 - val_accuracy: 0.5895 - val_loss: 0.6713
# Epoch 25/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.5923 - loss: 0.6545
# Test accuracy at epoch 25: 0.6102
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - accuracy: 0.5924 - loss: 0.6545 - val_accuracy: 0.5684 - val_loss: 0.6748
# Epoch 26/120
# 11/12 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.7025 - loss: 0.6240
# Test accuracy at epoch 26: 0.6186
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - accuracy: 0.6985 - loss: 0.6257 - val_accuracy: 0.5789 - val_loss: 0.6805
# Epoch 27/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.6862 - loss: 0.6180
# Test accuracy at epoch 27: 0.6780
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - accuracy: 0.6857 - loss: 0.6179 - val_accuracy: 0.6211 - val_loss: 0.6690
# Epoch 28/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.6809 - loss: 0.5924
# Test accuracy at epoch 28: 0.6102
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - accuracy: 0.6822 - loss: 0.5915 - val_accuracy: 0.6000 - val_loss: 0.7035
# Epoch 29/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.7049 - loss: 0.5837
# Test accuracy at epoch 29: 0.6441
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - accuracy: 0.7031 - loss: 0.5851 - val_accuracy: 0.6105 - val_loss: 0.6711
# Epoch 30/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.7029 - loss: 0.6005
# Test accuracy at epoch 30: 0.6271
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - accuracy: 0.7037 - loss: 0.5988 - val_accuracy: 0.6632 - val_loss: 0.6499
# Epoch 31/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.7327 - loss: 0.5534
# Test accuracy at epoch 31: 0.6271
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - accuracy: 0.7320 - loss: 0.5546 - val_accuracy: 0.5789 - val_loss: 0.6694
# Epoch 32/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.6525 - loss: 0.5795
# Test accuracy at epoch 32: 0.6271
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 129ms/step - accuracy: 0.6563 - loss: 0.5773 - val_accuracy: 0.6947 - val_loss: 0.7043
# Epoch 33/120
# 11/12 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.6941 - loss: 0.6155
# Test accuracy at epoch 33: 0.6864
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - accuracy: 0.6979 - loss: 0.6098 - val_accuracy: 0.6842 - val_loss: 0.6261
# Epoch 34/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.7773 - loss: 0.4914
# Test accuracy at epoch 34: 0.7119
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.7756 - loss: 0.4925 - val_accuracy: 0.6737 - val_loss: 0.6312
# Epoch 35/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.7402 - loss: 0.5502
# Test accuracy at epoch 35: 0.6610
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - accuracy: 0.7394 - loss: 0.5525 - val_accuracy: 0.6842 - val_loss: 0.7106
# Epoch 36/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.6859 - loss: 0.5936
# Test accuracy at epoch 36: 0.6356
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - accuracy: 0.6887 - loss: 0.5914 - val_accuracy: 0.6842 - val_loss: 0.6811
# Epoch 37/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.7402 - loss: 0.5202
# Test accuracy at epoch 37: 0.6271
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - accuracy: 0.7394 - loss: 0.5203 - val_accuracy: 0.6842 - val_loss: 0.7101
# Epoch 38/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.7403 - loss: 0.4989
# Test accuracy at epoch 38: 0.6949
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - accuracy: 0.7401 - loss: 0.5032 - val_accuracy: 0.6632 - val_loss: 0.6688
# Epoch 39/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.6491 - loss: 0.6205
# Test accuracy at epoch 39: 0.6356
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - accuracy: 0.6477 - loss: 0.6224 - val_accuracy: 0.5474 - val_loss: 0.6623
# Epoch 40/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.6236 - loss: 0.6000
# Test accuracy at epoch 40: 0.7288
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.6248 - loss: 0.5990 - val_accuracy: 0.6737 - val_loss: 0.6053
# Epoch 41/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.8026 - loss: 0.5086
# Test accuracy at epoch 41: 0.6780
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - accuracy: 0.8010 - loss: 0.5088 - val_accuracy: 0.6526 - val_loss: 0.6205
# Epoch 42/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.7923 - loss: 0.4580
# Test accuracy at epoch 42: 0.7373
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - accuracy: 0.7919 - loss: 0.4588 - val_accuracy: 0.7158 - val_loss: 0.6140
# Epoch 43/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.8261 - loss: 0.4205
# Test accuracy at epoch 43: 0.7373
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - accuracy: 0.8252 - loss: 0.4228 - val_accuracy: 0.7053 - val_loss: 0.6398
# Epoch 44/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.7855 - loss: 0.4856
# Test accuracy at epoch 44: 0.7881
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - accuracy: 0.7836 - loss: 0.4861 - val_accuracy: 0.7474 - val_loss: 0.5324
# Epoch 45/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.8286 - loss: 0.4537
# Test accuracy at epoch 45: 0.7288
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - accuracy: 0.8275 - loss: 0.4544 - val_accuracy: 0.7053 - val_loss: 0.5429
# Epoch 46/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.8394 - loss: 0.3983
# Test accuracy at epoch 46: 0.7203
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.8378 - loss: 0.4000 - val_accuracy: 0.7579 - val_loss: 0.6051
# Epoch 47/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.8230 - loss: 0.4269
# Test accuracy at epoch 47: 0.6780
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.8223 - loss: 0.4266 - val_accuracy: 0.7053 - val_loss: 0.8268
# Epoch 48/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.7351 - loss: 0.4948
# Test accuracy at epoch 48: 0.6864
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - accuracy: 0.7337 - loss: 0.4978 - val_accuracy: 0.6842 - val_loss: 0.6223
# Epoch 49/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.8403 - loss: 0.4435
# Test accuracy at epoch 49: 0.7034
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - accuracy: 0.8379 - loss: 0.4449 - val_accuracy: 0.6842 - val_loss: 0.7159
# Epoch 50/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.8099 - loss: 0.4290
# Test accuracy at epoch 50: 0.7119
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - accuracy: 0.8106 - loss: 0.4283 - val_accuracy: 0.7158 - val_loss: 0.6446
# Epoch 51/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.8656 - loss: 0.3356
# Test accuracy at epoch 51: 0.6780
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step - accuracy: 0.8648 - loss: 0.3368 - val_accuracy: 0.6842 - val_loss: 0.6575
# Epoch 52/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.8357 - loss: 0.3740
# Test accuracy at epoch 52: 0.7119
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step - accuracy: 0.8347 - loss: 0.3758 - val_accuracy: 0.7158 - val_loss: 0.6780
# Epoch 53/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.8337 - loss: 0.3772
# Test accuracy at epoch 53: 0.7458
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - accuracy: 0.8312 - loss: 0.3800 - val_accuracy: 0.7263 - val_loss: 0.6138
# Epoch 54/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.8698 - loss: 0.3891
# Test accuracy at epoch 54: 0.7542
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step - accuracy: 0.8704 - loss: 0.3857 - val_accuracy: 0.7684 - val_loss: 0.5227
# Epoch 55/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.8669 - loss: 0.3079
# Test accuracy at epoch 55: 0.7373
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step - accuracy: 0.8677 - loss: 0.3082 - val_accuracy: 0.7895 - val_loss: 0.4780
# Epoch 56/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.8864 - loss: 0.2944
# Test accuracy at epoch 56: 0.7712
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.8847 - loss: 0.2968 - val_accuracy: 0.8105 - val_loss: 0.4706
# Epoch 57/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.8514 - loss: 0.3345
# Test accuracy at epoch 57: 0.7627
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step - accuracy: 0.8520 - loss: 0.3335 - val_accuracy: 0.7474 - val_loss: 0.5822
# Epoch 58/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.8864 - loss: 0.2745
# Test accuracy at epoch 58: 0.7881
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.8853 - loss: 0.2771 - val_accuracy: 0.8105 - val_loss: 0.3788
# Epoch 59/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.8912 - loss: 0.2552
# Test accuracy at epoch 59: 0.7627
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - accuracy: 0.8906 - loss: 0.2563 - val_accuracy: 0.7579 - val_loss: 0.6288
# Epoch 60/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.8388 - loss: 0.3928
# Test accuracy at epoch 60: 0.6864
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - accuracy: 0.8390 - loss: 0.3931 - val_accuracy: 0.7684 - val_loss: 0.5522
# Epoch 61/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.8459 - loss: 0.3904
# Test accuracy at epoch 61: 0.7627
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - accuracy: 0.8439 - loss: 0.3923 - val_accuracy: 0.7789 - val_loss: 0.4971
# Epoch 62/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.8411 - loss: 0.3553
# Test accuracy at epoch 62: 0.7712
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - accuracy: 0.8421 - loss: 0.3545 - val_accuracy: 0.7368 - val_loss: 0.4868
# Epoch 63/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.8916 - loss: 0.2606
# Test accuracy at epoch 63: 0.7458
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - accuracy: 0.8912 - loss: 0.2624 - val_accuracy: 0.7579 - val_loss: 0.5238
# Epoch 64/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9162 - loss: 0.2228
# Test accuracy at epoch 64: 0.7712
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - accuracy: 0.9167 - loss: 0.2215 - val_accuracy: 0.7263 - val_loss: 0.5912
# Epoch 65/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.9263 - loss: 0.1838
# Test accuracy at epoch 65: 0.7627
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - accuracy: 0.9255 - loss: 0.1863 - val_accuracy: 0.7895 - val_loss: 0.4943
# Epoch 66/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.9493 - loss: 0.1683
# Test accuracy at epoch 66: 0.7119
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.9477 - loss: 0.1713 - val_accuracy: 0.7263 - val_loss: 0.7684
# Epoch 67/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.9185 - loss: 0.2079
# Test accuracy at epoch 67: 0.7458
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - accuracy: 0.9191 - loss: 0.2074 - val_accuracy: 0.7579 - val_loss: 0.6039
# Epoch 68/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.9320 - loss: 0.1796
# Test accuracy at epoch 68: 0.7627
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - accuracy: 0.9327 - loss: 0.1778 - val_accuracy: 0.8211 - val_loss: 0.4731
# Epoch 69/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.9407 - loss: 0.1624
# Test accuracy at epoch 69: 0.7542
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step - accuracy: 0.9410 - loss: 0.1608 - val_accuracy: 0.8000 - val_loss: 0.6609
# Epoch 70/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9490 - loss: 0.1486
# Test accuracy at epoch 70: 0.7373
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - accuracy: 0.9480 - loss: 0.1504 - val_accuracy: 0.7895 - val_loss: 0.6578
# Epoch 71/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.9597 - loss: 0.1261
# Test accuracy at epoch 71: 0.7881
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - accuracy: 0.9585 - loss: 0.1275 - val_accuracy: 0.8211 - val_loss: 0.4385
# Epoch 72/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9624 - loss: 0.1119
# Test accuracy at epoch 72: 0.6017
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - accuracy: 0.9608 - loss: 0.1163 - val_accuracy: 0.6947 - val_loss: 0.9873
# Epoch 73/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.7737 - loss: 0.5302
# Test accuracy at epoch 73: 0.7542
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - accuracy: 0.7717 - loss: 0.5338 - val_accuracy: 0.7263 - val_loss: 0.4705
# Epoch 74/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.7487 - loss: 0.4841
# Test accuracy at epoch 74: 0.8051
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - accuracy: 0.7513 - loss: 0.4809 - val_accuracy: 0.7579 - val_loss: 0.5031
# Epoch 75/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.8606 - loss: 0.3324
# Test accuracy at epoch 75: 0.7712
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - accuracy: 0.8620 - loss: 0.3307 - val_accuracy: 0.7895 - val_loss: 0.4591
# Epoch 76/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9072 - loss: 0.2288
# Test accuracy at epoch 76: 0.7712
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - accuracy: 0.9070 - loss: 0.2297 - val_accuracy: 0.7789 - val_loss: 0.4635
# Epoch 77/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9110 - loss: 0.2277
# Test accuracy at epoch 77: 0.7627
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.9123 - loss: 0.2249 - val_accuracy: 0.8211 - val_loss: 0.4642
# Epoch 78/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9638 - loss: 0.1315
# Test accuracy at epoch 78: 0.7966
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - accuracy: 0.9635 - loss: 0.1312 - val_accuracy: 0.8211 - val_loss: 0.5024
# Epoch 79/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.9728 - loss: 0.0844
# Test accuracy at epoch 79: 0.7627
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.9722 - loss: 0.0853 - val_accuracy: 0.8211 - val_loss: 0.6189
# Epoch 80/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9915 - loss: 0.0461
# Test accuracy at epoch 80: 0.7966
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.9912 - loss: 0.0469 - val_accuracy: 0.8000 - val_loss: 0.7270
# Epoch 81/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9870 - loss: 0.0497
# Test accuracy at epoch 81: 0.7881
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - accuracy: 0.9866 - loss: 0.0502 - val_accuracy: 0.8105 - val_loss: 0.6841
# Epoch 82/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.9836 - loss: 0.0602
# Test accuracy at epoch 82: 0.8136
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - accuracy: 0.9832 - loss: 0.0610 - val_accuracy: 0.8316 - val_loss: 0.6110
# Epoch 83/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.9749 - loss: 0.0797
# Test accuracy at epoch 83: 0.8051
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.9745 - loss: 0.0810 - val_accuracy: 0.8000 - val_loss: 0.8704
# Epoch 84/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9783 - loss: 0.0914
# Test accuracy at epoch 84: 0.7797
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - accuracy: 0.9789 - loss: 0.0894 - val_accuracy: 0.8105 - val_loss: 0.6282
# Epoch 85/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.9939 - loss: 0.0339
# Test accuracy at epoch 85: 0.8136
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - accuracy: 0.9938 - loss: 0.0336 - val_accuracy: 0.8105 - val_loss: 0.6841
# Epoch 86/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.9963 - loss: 0.0158
# Test accuracy at epoch 86: 0.8220
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - accuracy: 0.9960 - loss: 0.0165 - val_accuracy: 0.7895 - val_loss: 0.8318
# Epoch 87/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.9780 - loss: 0.0729
# Test accuracy at epoch 87: 0.7881
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.9760 - loss: 0.0797 - val_accuracy: 0.7789 - val_loss: 0.7514
# Epoch 88/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.8967 - loss: 0.2683
# Test accuracy at epoch 88: 0.6949
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.8967 - loss: 0.2682 - val_accuracy: 0.6947 - val_loss: 0.7800
# Epoch 89/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.8594 - loss: 0.3104
# Test accuracy at epoch 89: 0.7458
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - accuracy: 0.8621 - loss: 0.3062 - val_accuracy: 0.7684 - val_loss: 0.5262
# Epoch 90/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9333 - loss: 0.1666
# Test accuracy at epoch 90: 0.8051
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - accuracy: 0.9348 - loss: 0.1642 - val_accuracy: 0.8105 - val_loss: 0.5596
# Epoch 91/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.9848 - loss: 0.0549
# Test accuracy at epoch 91: 0.7881
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.9844 - loss: 0.0554 - val_accuracy: 0.8000 - val_loss: 0.6561
# Epoch 92/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.9962 - loss: 0.0235
# Test accuracy at epoch 92: 0.7627
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.9959 - loss: 0.0242 - val_accuracy: 0.7895 - val_loss: 0.8876
# Epoch 93/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9954 - loss: 0.0244
# Test accuracy at epoch 93: 0.7712
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - accuracy: 0.9953 - loss: 0.0245 - val_accuracy: 0.7789 - val_loss: 0.8303
# Epoch 94/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 1.0000 - loss: 0.0155
# Test accuracy at epoch 94: 0.7797
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - accuracy: 1.0000 - loss: 0.0151 - val_accuracy: 0.7684 - val_loss: 1.0437
# Epoch 95/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 1.0000 - loss: 0.0069
# Test accuracy at epoch 95: 0.7542
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - accuracy: 1.0000 - loss: 0.0068 - val_accuracy: 0.8211 - val_loss: 0.9148
# Epoch 96/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 1.0000 - loss: 0.0053
# Test accuracy at epoch 96: 0.7966
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 1.0000 - loss: 0.0053 - val_accuracy: 0.7789 - val_loss: 0.8938
# Epoch 97/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 1.0000 - loss: 0.0037
# Test accuracy at epoch 97: 0.7797
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 0.8211 - val_loss: 0.8706
# Epoch 98/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 1.0000 - loss: 0.0026
# Test accuracy at epoch 98: 0.7712
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.8316 - val_loss: 0.9041
# Epoch 99/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 1.0000 - loss: 0.0025
# Test accuracy at epoch 99: 0.7797
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.7895 - val_loss: 1.0428
# Epoch 100/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 1.0000 - loss: 0.0022
# Test accuracy at epoch 100: 0.7966
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.7789 - val_loss: 1.1858
# Epoch 101/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 1.0000 - loss: 0.0014
# Test accuracy at epoch 101: 0.7797
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.7895 - val_loss: 1.1915
# Epoch 102/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 1.0000 - loss: 0.0011
# Test accuracy at epoch 102: 0.7712
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.8000 - val_loss: 1.2503
# Epoch 103/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 1.0000 - loss: 6.0942e-04
# Test accuracy at epoch 103: 0.7797
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - accuracy: 1.0000 - loss: 6.1863e-04 - val_accuracy: 0.7789 - val_loss: 1.3418
# Epoch 104/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 1.0000 - loss: 7.0476e-04
# Test accuracy at epoch 104: 0.7797
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - accuracy: 1.0000 - loss: 7.0314e-04 - val_accuracy: 0.7789 - val_loss: 1.3776
# Epoch 105/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 1.0000 - loss: 8.4363e-04
# Test accuracy at epoch 105: 0.7712
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - accuracy: 1.0000 - loss: 8.2727e-04 - val_accuracy: 0.7789 - val_loss: 1.3920
# Epoch 106/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 1.0000 - loss: 7.5575e-04
# Test accuracy at epoch 106: 0.7627
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 1.0000 - loss: 7.5163e-04 - val_accuracy: 0.7789 - val_loss: 1.4140
# Epoch 107/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 1.0000 - loss: 4.6749e-04
# Test accuracy at epoch 107: 0.7627
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - accuracy: 1.0000 - loss: 4.7997e-04 - val_accuracy: 0.7789 - val_loss: 1.4320
# Epoch 108/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 1.0000 - loss: 4.3438e-04
# Test accuracy at epoch 108: 0.7797
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 1.0000 - loss: 4.3112e-04 - val_accuracy: 0.7789 - val_loss: 1.4692
# Epoch 109/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 1.0000 - loss: 3.2293e-04
# Test accuracy at epoch 109: 0.7797
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - accuracy: 1.0000 - loss: 3.3003e-04 - val_accuracy: 0.7789 - val_loss: 1.4807
# Epoch 110/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 1.0000 - loss: 3.3252e-04
# Test accuracy at epoch 110: 0.7712
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 1.0000 - loss: 3.3587e-04 - val_accuracy: 0.7789 - val_loss: 1.4878
# Epoch 111/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 1.0000 - loss: 3.9441e-04
# Test accuracy at epoch 111: 0.7712
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 1.0000 - loss: 3.9757e-04 - val_accuracy: 0.7789 - val_loss: 1.4989
# Epoch 112/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 1.0000 - loss: 4.5244e-04
# Test accuracy at epoch 112: 0.7797
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 118ms/step - accuracy: 1.0000 - loss: 4.5301e-04 - val_accuracy: 0.7789 - val_loss: 1.5170
# Epoch 113/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 1.0000 - loss: 6.0467e-04
# Test accuracy at epoch 113: 0.7712
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 114ms/step - accuracy: 1.0000 - loss: 5.9226e-04 - val_accuracy: 0.7789 - val_loss: 1.5101
# Epoch 114/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 1.0000 - loss: 2.6499e-04
# Test accuracy at epoch 114: 0.7712
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 115ms/step - accuracy: 1.0000 - loss: 2.6861e-04 - val_accuracy: 0.7789 - val_loss: 1.5317
# Epoch 115/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 1.0000 - loss: 3.1800e-04
# Test accuracy at epoch 115: 0.7712
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 1.0000 - loss: 3.1818e-04 - val_accuracy: 0.7895 - val_loss: 1.5491
# Epoch 116/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 1.0000 - loss: 3.9907e-04
# Test accuracy at epoch 116: 0.7712
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 114ms/step - accuracy: 1.0000 - loss: 3.9937e-04 - val_accuracy: 0.7789 - val_loss: 1.5807
# Epoch 117/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 1.0000 - loss: 2.7197e-04
# Test accuracy at epoch 117: 0.7797
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 1.0000 - loss: 2.7375e-04 - val_accuracy: 0.7789 - val_loss: 1.6314
# Epoch 118/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 1.0000 - loss: 4.4668e-04
# Test accuracy at epoch 118: 0.7797
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - accuracy: 1.0000 - loss: 4.3585e-04 - val_accuracy: 0.7684 - val_loss: 1.6614
# Epoch 119/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 1.0000 - loss: 6.0679e-04
# Test accuracy at epoch 119: 0.7712
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - accuracy: 1.0000 - loss: 5.9189e-04 - val_accuracy: 0.7895 - val_loss: 1.6053
# Epoch 120/120
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 1.0000 - loss: 2.2956e-04
# Test accuracy at epoch 120: 0.7627
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step - accuracy: 1.0000 - loss: 2.2956e-04 - val_accuracy: 0.7895 - val_loss: 1.5807
# Test accuracy: 0.7627
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step
# WARNING:tensorflow:5 out of the last 8 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000014B9B783F60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step
# Predicted cell type: ('rigid', 7.078371e-13, 1.0)
# WARNING:tensorflow:6 out of the last 9 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000014B9B783F60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
