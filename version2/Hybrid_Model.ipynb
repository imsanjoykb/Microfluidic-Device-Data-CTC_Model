# %% [markdown]
# ### Hybrid Model: CNN + LSTM

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf  # Import TensorFlow
from sklearn.metrics import roc_curve, auc
from sklearn.model_selection import train_test_split 
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv1D, MaxPooling1D, GlobalAveragePooling1D, Dense, LSTM, concatenate, Dropout
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical

def load_data(directory, cell_type):
    position_data = []
    velocity_data = []
    labels = []
    for filename in os.listdir(directory):
        if filename.endswith('.csv'):
            df = pd.read_csv(os.path.join(directory, filename))
            position = df[['X', 'Y', 'Z']].values
            velocity = df[['velocity_x', 'velocity_y', 'velocity_z']].values
            position_data.append(position)
            velocity_data.append(velocity)
            labels.append(cell_type)
    return position_data, velocity_data, labels

# Load PLT and WBC data
soft_position, soft_velocity, soft_labels = load_data('D:/Assessment/PINN/LSTM-Problem/NewTimeSeriesDataForCells/soft_dir', 0)
rigid_position, rigid_velocity, rigid_labels = load_data('D:/Assessment/PINN/LSTM-Problem/NewTimeSeriesDataForCells/hard_dir', 1)

# Combine data and labels
all_position_data = soft_position + rigid_position
all_velocity_data = soft_velocity + rigid_velocity
all_labels = soft_labels + rigid_labels

# Pad sequences to the same length
max_length = max(max(len(seq) for seq in all_position_data), max(len(seq) for seq in all_velocity_data))
padded_position_data = pad_sequences(all_position_data, maxlen=max_length, dtype='float32', padding='post', truncating='post')
padded_velocity_data = pad_sequences(all_velocity_data, maxlen=max_length, dtype='float32', padding='post', truncating='post')

# Normalize the data
position_scaler = StandardScaler()
velocity_scaler = StandardScaler()

normalized_position_data = np.array([position_scaler.fit_transform(seq) for seq in padded_position_data])
normalized_velocity_data = np.array([velocity_scaler.fit_transform(seq) for seq in padded_velocity_data])

# Convert labels to categorical
labels = to_categorical(all_labels)

# Split the data into training and testing sets
X_pos_train, X_pos_test, X_vel_train, X_vel_test, y_train, y_test = train_test_split(
    normalized_position_data, normalized_velocity_data, labels, test_size=0.2, random_state=42)

def create_hybrid_model(input_shape):
    # Separate inputs for position and velocity
    position_input = Input(shape=input_shape)
    velocity_input = Input(shape=input_shape)

    # Convolutions for position
    x_pos = Conv1D(64, kernel_size=3, activation='relu')(position_input)
    x_pos = MaxPooling1D(2)(x_pos)
    x_pos = Conv1D(64, kernel_size=3, activation='relu')(x_pos)
    x_pos = LSTM(64, return_sequences=True)(x_pos)
    x_pos = GlobalAveragePooling1D()(x_pos)

    # Convolutions for velocity
    x_vel = Conv1D(64, kernel_size=3, activation='relu')(velocity_input)
    x_vel = MaxPooling1D(2)(x_vel)
    x_vel = Conv1D(64, kernel_size=3, activation='relu')(x_vel)
    x_vel = LSTM(64, return_sequences=True)(x_vel)
    x_vel = GlobalAveragePooling1D()(x_vel)

    # Combine features
    combined = concatenate([x_pos, x_vel])

    # Dense layers
    x = Dense(128, activation='relu')(combined)
    x = Dropout(0.5)(x)
    x = Dense(64, activation='relu')(x)
    output = Dense(2, activation='softmax')(x)

    # Create model
    model = Model(inputs=[position_input, velocity_input], outputs=output)
    return model

def create_all_outputs_model(model):
    return Model(inputs=model.inputs, outputs=[layer.output for layer in model.layers])

input_shape = (max_length, 3)  # 3 features for both position and velocity
model = create_hybrid_model(input_shape)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Print model summary
model.summary()

# Custom callback to track test accuracy
class TestAccuracyCallback(tf.keras.callbacks.Callback):
    def __init__(self, test_data):
        self.test_data = test_data
        self.test_accuracies = []

    def on_epoch_end(self, epoch, logs=None):
        X_pos_test, X_vel_test, y_test = self.test_data
        test_loss, test_accuracy = self.model.evaluate([X_pos_test, X_vel_test], y_test, verbose=0)
        self.test_accuracies.append(test_accuracy)
        print(f'\nTest accuracy at epoch {epoch+1}: {test_accuracy:.4f}')

# Instantiate the callback
test_accuracy_callback = TestAccuracyCallback((X_pos_test, X_vel_test, y_test))

# Train the model with the custom callback included
cnn_history = model.fit(
    [X_pos_train, X_vel_train], y_train,
    epochs=100,
    batch_size=32,
    validation_split=0.2,
    verbose=1,
    callbacks=[test_accuracy_callback]
)

all_outputs_model = create_all_outputs_model(model)

# Evaluate the model
test_loss, test_accuracy = model.evaluate([X_pos_test, X_vel_test], y_test, verbose=0)
print(f"Test accuracy: {test_accuracy:.4f}")

# Plot for Training, Validation, and Test Accuracy
plt.figure(figsize=(7, 6))

# Apply seaborn style and color palette
sns.set(style="whitegrid")
colors = sns.color_palette("muted")

plt.plot(cnn_history.history['accuracy'], label='Training Accuracy', color=colors[0], linestyle='--', linewidth=2, marker='o', markersize=5)
plt.plot(cnn_history.history['val_accuracy'], label='Validation Accuracy', color=colors[1], linestyle='--', linewidth=2, marker='s', markersize=5)
plt.plot(test_accuracy_callback.test_accuracies, label='Test Accuracy', color='green', linestyle='--', linewidth=2, marker='^', markersize=5)

plt.title('Accuracy Curve CNN+LSTM', fontsize=16, fontweight='bold')
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Accuracy', fontsize=14)
plt.legend(fontsize=12, shadow=True)
plt.grid(True, linestyle='--', alpha=0.6)

plt.tight_layout()
plt.show()

sample_pos = X_pos_test[:1]
sample_vel = X_vel_test[:1]

all_layer_outputs = all_outputs_model.predict([sample_pos, sample_vel])

# Prediction for a sample
def predict_cell_type(trajectory):
    new_position = new_trajectory[:, :3]
    new_velocity = new_trajectory[:, 3:]
    padded_position = pad_sequences([new_position], maxlen=max_length, dtype='float32', padding='post', truncating='post')
    padded_velocity = pad_sequences([new_velocity], maxlen=max_length, dtype='float32', padding='post', truncating='post')
    normalized_position = position_scaler.transform(padded_position[0])
    normalized_velocity = velocity_scaler.transform(padded_velocity[0])
    position_trajectory = normalized_position.reshape(1, max_length, 3)
    velocity_trajectory = normalized_velocity.reshape(1, max_length, 3)
    prediction = model.predict([position_trajectory, velocity_trajectory])
    cell_type = "soft" if prediction[0][0] > prediction[0][1] else "rigid"
    return cell_type, prediction[0][0], prediction[0][1]

example_csv_path = 'D:/Assessment/PINN/LSTM-Problem/NewTimeSeriesDataForCells/hard_dir/output_0.0 (1)_split_1.csv'
new_trajectory = pd.read_csv(example_csv_path)[['X', 'Y', 'Z','velocity_x', 'velocity_y', 'velocity_z']].values
predicted_cell_type_1 = predict_cell_type(new_trajectory)
print(f"Predicted cell type: {predicted_cell_type_1}")

# Apply seaborn style and color palette
sns.set(style="whitegrid")
colors = sns.color_palette("muted")

# Compute ROC curve and ROC area for the model
y_pred = model.predict([X_pos_test, X_vel_test])
fpr, tpr, _ = roc_curve(y_test[:, 1], y_pred[:, 1])
roc_auc = auc(fpr, tpr)

# Plot for ROC curve
plt.figure(figsize=(7, 6))

plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})', marker='o', markersize=5)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=14)
plt.ylabel('True Positive Rate', fontsize=14)
plt.title('Receiver Operating Characteristic (ROC) Curve (CNN+LSTM)', fontsize=16, fontweight='bold')
plt.legend(loc="lower right", fontsize=12, shadow=True)
plt.grid(True, linestyle='--', alpha=0.6)

plt.tight_layout()
plt.show()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 431, 3)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_1       │ (None, 431, 3)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d (Conv1D)     │ (None, 429, 64)   │        640 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_2 (Conv1D)   │ (None, 429, 64)   │        640 │ input_layer_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d       │ (None, 214, 64)   │          0 │ conv1d[0][0]      │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_1     │ (None, 214, 64)   │          0 │ conv1d_2[0][0]    │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_1 (Conv1D)   │ (None, 212, 64)   │     12,352 │ max_pooling1d[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_3 (Conv1D)   │ (None, 212, 64)   │     12,352 │ max_pooling1d_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm (LSTM)         │ (None, 212, 64)   │     33,024 │ conv1d_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_1 (LSTM)       │ (None, 212, 64)   │     33,024 │ conv1d_3[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 64)        │          0 │ lstm[0][0]        │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 64)        │          0 │ lstm_1[0][0]      │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 128)       │          0 │ global_average_p… │
# │ (Concatenate)       │                   │            │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 128)       │     16,512 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 128)       │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 64)        │      8,256 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 2)         │        130 │ dense_1[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 116,930 (456.76 KB)
#  Trainable params: 116,930 (456.76 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# d:\Assessment\Microfluidic-Device-Data-CTC_Model\myenv\lib\site-packages\keras\src\models\functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['keras_tensor', 'keras_tensor_1']. Received: the structure of inputs=('*', '*')
#   warnings.warn(
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.5041 - loss: 0.6976
# Test accuracy at epoch 1: 0.5763
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 7s 198ms/step - accuracy: 0.5064 - loss: 0.6974 - val_accuracy: 0.5368 - val_loss: 0.6913
# Epoch 2/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.5457 - loss: 0.6862
# Test accuracy at epoch 2: 0.5763
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 202ms/step - accuracy: 0.5461 - loss: 0.6860 - val_accuracy: 0.5368 - val_loss: 0.6936
# Epoch 3/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.5507 - loss: 0.6922
# Test accuracy at epoch 3: 0.5763
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.5508 - loss: 0.6922 - val_accuracy: 0.5368 - val_loss: 0.6926
# Epoch 4/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.5893 - loss: 0.6739
# Test accuracy at epoch 4: 0.5763
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 135ms/step - accuracy: 0.5873 - loss: 0.6744 - val_accuracy: 0.5368 - val_loss: 0.6906
# Epoch 5/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.5705 - loss: 0.6747
# Test accuracy at epoch 5: 0.5847
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 188ms/step - accuracy: 0.5702 - loss: 0.6753 - val_accuracy: 0.5474 - val_loss: 0.6906
# Epoch 6/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.5433 - loss: 0.6847
# Test accuracy at epoch 6: 0.5847
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 201ms/step - accuracy: 0.5426 - loss: 0.6847 - val_accuracy: 0.5368 - val_loss: 0.6919
# Epoch 7/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.5679 - loss: 0.6875
# Test accuracy at epoch 7: 0.5847
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 154ms/step - accuracy: 0.5691 - loss: 0.6870 - val_accuracy: 0.5474 - val_loss: 0.6946
# Epoch 8/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.5618 - loss: 0.6863
# Test accuracy at epoch 8: 0.6356
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 132ms/step - accuracy: 0.5643 - loss: 0.6855 - val_accuracy: 0.5368 - val_loss: 0.6961
# Epoch 9/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.6295 - loss: 0.6499
# Test accuracy at epoch 9: 0.6356
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 134ms/step - accuracy: 0.6255 - loss: 0.6524 - val_accuracy: 0.5368 - val_loss: 0.6995
# Epoch 10/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.5926 - loss: 0.6759
# Test accuracy at epoch 10: 0.5763
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 134ms/step - accuracy: 0.5911 - loss: 0.6766 - val_accuracy: 0.5263 - val_loss: 0.6900
# Epoch 11/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.5405 - loss: 0.6854
# Test accuracy at epoch 11: 0.5763
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 129ms/step - accuracy: 0.5426 - loss: 0.6851 - val_accuracy: 0.5263 - val_loss: 0.6905
# Epoch 12/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.5438 - loss: 0.6821
# Test accuracy at epoch 12: 0.5763
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 128ms/step - accuracy: 0.5444 - loss: 0.6822 - val_accuracy: 0.5263 - val_loss: 0.6934
# Epoch 13/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.5741 - loss: 0.6839
# Test accuracy at epoch 13: 0.5932
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 117ms/step - accuracy: 0.5752 - loss: 0.6837 - val_accuracy: 0.5263 - val_loss: 0.6898
# Epoch 14/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.6297 - loss: 0.6728
# Test accuracy at epoch 14: 0.6017
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 125ms/step - accuracy: 0.6284 - loss: 0.6729 - val_accuracy: 0.5368 - val_loss: 0.6912
# Epoch 15/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.5674 - loss: 0.6816
# Test accuracy at epoch 15: 0.6271
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 148ms/step - accuracy: 0.5701 - loss: 0.6809 - val_accuracy: 0.5368 - val_loss: 0.6928
# Epoch 16/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.6063 - loss: 0.6656
# Test accuracy at epoch 16: 0.6102
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 134ms/step - accuracy: 0.6078 - loss: 0.6657 - val_accuracy: 0.5579 - val_loss: 0.6901
# Epoch 17/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.6004 - loss: 0.6621
# Test accuracy at epoch 17: 0.6102
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 133ms/step - accuracy: 0.6020 - loss: 0.6618 - val_accuracy: 0.5579 - val_loss: 0.7138
# Epoch 18/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.6482 - loss: 0.6513
# Test accuracy at epoch 18: 0.6186
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 127ms/step - accuracy: 0.6477 - loss: 0.6509 - val_accuracy: 0.5368 - val_loss: 0.7055
# Epoch 19/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.6643 - loss: 0.6410
# Test accuracy at epoch 19: 0.5932
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 130ms/step - accuracy: 0.6630 - loss: 0.6411 - val_accuracy: 0.5579 - val_loss: 0.6841
# Epoch 20/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.6214 - loss: 0.6399
# Test accuracy at epoch 20: 0.5932
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 141ms/step - accuracy: 0.6215 - loss: 0.6400 - val_accuracy: 0.5684 - val_loss: 0.6771
# Epoch 21/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.6841 - loss: 0.6086
# Test accuracy at epoch 21: 0.5678
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - accuracy: 0.6829 - loss: 0.6104 - val_accuracy: 0.5789 - val_loss: 0.6792
# Epoch 22/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.6131 - loss: 0.6512
# Test accuracy at epoch 22: 0.6017
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.6155 - loss: 0.6499 - val_accuracy: 0.5789 - val_loss: 0.6638
# Epoch 23/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.6739 - loss: 0.6089
# Test accuracy at epoch 23: 0.6271
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.6735 - loss: 0.6088 - val_accuracy: 0.5895 - val_loss: 0.6653
# Epoch 24/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.6987 - loss: 0.6110
# Test accuracy at epoch 24: 0.6102
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - accuracy: 0.6990 - loss: 0.6098 - val_accuracy: 0.5895 - val_loss: 0.7235
# Epoch 25/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.7032 - loss: 0.5831
# Test accuracy at epoch 25: 0.5000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.7019 - loss: 0.5851 - val_accuracy: 0.5263 - val_loss: 0.7002
# Epoch 26/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.5993 - loss: 0.6379
# Test accuracy at epoch 26: 0.5593
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.6033 - loss: 0.6358 - val_accuracy: 0.5895 - val_loss: 0.6608
# Epoch 27/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.6481 - loss: 0.6151
# Test accuracy at epoch 27: 0.6441
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 115ms/step - accuracy: 0.6505 - loss: 0.6136 - val_accuracy: 0.5895 - val_loss: 0.6510
# Epoch 28/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.6710 - loss: 0.5909
# Test accuracy at epoch 28: 0.6017
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step - accuracy: 0.6741 - loss: 0.5887 - val_accuracy: 0.6421 - val_loss: 0.7248
# Epoch 29/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.7269 - loss: 0.5779
# Test accuracy at epoch 29: 0.5508
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - accuracy: 0.7277 - loss: 0.5760 - val_accuracy: 0.6316 - val_loss: 0.6381
# Epoch 30/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.6754 - loss: 0.5933
# Test accuracy at epoch 30: 0.6102
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 108ms/step - accuracy: 0.6755 - loss: 0.5942 - val_accuracy: 0.6211 - val_loss: 0.7262
# Epoch 31/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.5869 - loss: 0.6538
# Test accuracy at epoch 31: 0.5593
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - accuracy: 0.5848 - loss: 0.6543 - val_accuracy: 0.6105 - val_loss: 0.6528
# Epoch 32/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.7073 - loss: 0.5881
# Test accuracy at epoch 32: 0.6186
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 108ms/step - accuracy: 0.7069 - loss: 0.5872 - val_accuracy: 0.6316 - val_loss: 0.6383
# Epoch 33/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.6946 - loss: 0.5765
# Test accuracy at epoch 33: 0.6017
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - accuracy: 0.6977 - loss: 0.5742 - val_accuracy: 0.6632 - val_loss: 0.7201
# Epoch 34/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.7353 - loss: 0.5219
# Test accuracy at epoch 34: 0.6780
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - accuracy: 0.7353 - loss: 0.5229 - val_accuracy: 0.6316 - val_loss: 0.6213
# Epoch 35/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.7713 - loss: 0.4993
# Test accuracy at epoch 35: 0.4831
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.7691 - loss: 0.5012 - val_accuracy: 0.5579 - val_loss: 0.6873
# Epoch 36/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.7173 - loss: 0.5549
# Test accuracy at epoch 36: 0.6610
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.7173 - loss: 0.5548 - val_accuracy: 0.6842 - val_loss: 0.5852
# Epoch 37/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.7286 - loss: 0.5424
# Test accuracy at epoch 37: 0.6525
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 114ms/step - accuracy: 0.7293 - loss: 0.5422 - val_accuracy: 0.6316 - val_loss: 0.6429
# Epoch 38/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.7545 - loss: 0.4910
# Test accuracy at epoch 38: 0.6780
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 117ms/step - accuracy: 0.7558 - loss: 0.4911 - val_accuracy: 0.6842 - val_loss: 0.5723
# Epoch 39/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.7337 - loss: 0.5220
# Test accuracy at epoch 39: 0.6864
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 117ms/step - accuracy: 0.7350 - loss: 0.5202 - val_accuracy: 0.7158 - val_loss: 0.5924
# Epoch 40/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.7547 - loss: 0.5305
# Test accuracy at epoch 40: 0.6949
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step - accuracy: 0.7576 - loss: 0.5255 - val_accuracy: 0.6737 - val_loss: 0.6276
# Epoch 41/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.7862 - loss: 0.4552
# Test accuracy at epoch 41: 0.6356
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - accuracy: 0.7836 - loss: 0.4576 - val_accuracy: 0.7053 - val_loss: 0.5720
# Epoch 42/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.8060 - loss: 0.4239
# Test accuracy at epoch 42: 0.6695
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step - accuracy: 0.8038 - loss: 0.4272 - val_accuracy: 0.6737 - val_loss: 0.6655
# Epoch 43/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.8052 - loss: 0.4159
# Test accuracy at epoch 43: 0.6695
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 130ms/step - accuracy: 0.8027 - loss: 0.4210 - val_accuracy: 0.6947 - val_loss: 0.5467
# Epoch 44/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.7785 - loss: 0.4667
# Test accuracy at epoch 44: 0.7288
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 128ms/step - accuracy: 0.7788 - loss: 0.4661 - val_accuracy: 0.7053 - val_loss: 0.5679
# Epoch 45/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.7815 - loss: 0.4540
# Test accuracy at epoch 45: 0.6610
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 120ms/step - accuracy: 0.7802 - loss: 0.4575 - val_accuracy: 0.6737 - val_loss: 0.6408
# Epoch 46/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.7329 - loss: 0.5107
# Test accuracy at epoch 46: 0.6695
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 120ms/step - accuracy: 0.7336 - loss: 0.5107 - val_accuracy: 0.7053 - val_loss: 0.5582
# Epoch 47/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.7584 - loss: 0.5020
# Test accuracy at epoch 47: 0.6780
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.7612 - loss: 0.4988 - val_accuracy: 0.7158 - val_loss: 0.5495
# Epoch 48/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.8259 - loss: 0.3984
# Test accuracy at epoch 48: 0.7034
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - accuracy: 0.8256 - loss: 0.3992 - val_accuracy: 0.7368 - val_loss: 0.5663
# Epoch 49/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.8396 - loss: 0.3799
# Test accuracy at epoch 49: 0.7034
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - accuracy: 0.8387 - loss: 0.3811 - val_accuracy: 0.7263 - val_loss: 0.6059
# Epoch 50/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.7832 - loss: 0.4421
# Test accuracy at epoch 50: 0.6864
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - accuracy: 0.7840 - loss: 0.4423 - val_accuracy: 0.6842 - val_loss: 0.6151
# Epoch 51/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.8113 - loss: 0.4200
# Test accuracy at epoch 51: 0.6271
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - accuracy: 0.8109 - loss: 0.4213 - val_accuracy: 0.6947 - val_loss: 0.8549
# Epoch 52/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.7278 - loss: 0.4949
# Test accuracy at epoch 52: 0.6864
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - accuracy: 0.7302 - loss: 0.4933 - val_accuracy: 0.7053 - val_loss: 0.5365
# Epoch 53/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.8011 - loss: 0.4344
# Test accuracy at epoch 53: 0.6610
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.8021 - loss: 0.4329 - val_accuracy: 0.7789 - val_loss: 0.5186
# Epoch 54/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.8020 - loss: 0.4230
# Test accuracy at epoch 54: 0.7203
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - accuracy: 0.8044 - loss: 0.4214 - val_accuracy: 0.7579 - val_loss: 0.6252
# Epoch 55/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.8668 - loss: 0.3013
# Test accuracy at epoch 55: 0.6949
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - accuracy: 0.8654 - loss: 0.3035 - val_accuracy: 0.7474 - val_loss: 0.7101
# Epoch 56/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.8497 - loss: 0.3437
# Test accuracy at epoch 56: 0.7203
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - accuracy: 0.8498 - loss: 0.3438 - val_accuracy: 0.7263 - val_loss: 0.6133
# Epoch 57/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.8370 - loss: 0.3470
# Test accuracy at epoch 57: 0.6441
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - accuracy: 0.8369 - loss: 0.3481 - val_accuracy: 0.7474 - val_loss: 0.5934
# Epoch 58/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.8424 - loss: 0.3199
# Test accuracy at epoch 58: 0.6949
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.8423 - loss: 0.3213 - val_accuracy: 0.7368 - val_loss: 0.5906
# Epoch 59/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.8827 - loss: 0.3106
# Test accuracy at epoch 59: 0.7034
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - accuracy: 0.8823 - loss: 0.3104 - val_accuracy: 0.7368 - val_loss: 0.6194
# Epoch 60/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.8552 - loss: 0.3098
# Test accuracy at epoch 60: 0.6864
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 133ms/step - accuracy: 0.8567 - loss: 0.3081 - val_accuracy: 0.7474 - val_loss: 0.7042
# Epoch 61/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.8289 - loss: 0.3623
# Test accuracy at epoch 61: 0.6780
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 180ms/step - accuracy: 0.8269 - loss: 0.3650 - val_accuracy: 0.6737 - val_loss: 0.6358
# Epoch 62/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.8229 - loss: 0.3275
# Test accuracy at epoch 62: 0.7203
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 169ms/step - accuracy: 0.8230 - loss: 0.3299 - val_accuracy: 0.7474 - val_loss: 0.5612
# Epoch 63/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.8300 - loss: 0.3517
# Test accuracy at epoch 63: 0.7034
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 169ms/step - accuracy: 0.8304 - loss: 0.3520 - val_accuracy: 0.6947 - val_loss: 0.8005
# Epoch 64/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.8821 - loss: 0.2539
# Test accuracy at epoch 64: 0.6864
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 121ms/step - accuracy: 0.8810 - loss: 0.2573 - val_accuracy: 0.7158 - val_loss: 0.6097
# Epoch 65/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.8769 - loss: 0.2885
# Test accuracy at epoch 65: 0.6864
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 129ms/step - accuracy: 0.8772 - loss: 0.2876 - val_accuracy: 0.7789 - val_loss: 0.6257
# Epoch 66/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.9144 - loss: 0.2662
# Test accuracy at epoch 66: 0.7034
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 130ms/step - accuracy: 0.9137 - loss: 0.2652 - val_accuracy: 0.8000 - val_loss: 0.5798
# Epoch 67/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.8945 - loss: 0.2510
# Test accuracy at epoch 67: 0.7373
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - accuracy: 0.8945 - loss: 0.2504 - val_accuracy: 0.7895 - val_loss: 0.6368
# Epoch 68/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.8826 - loss: 0.2357
# Test accuracy at epoch 68: 0.7288
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 108ms/step - accuracy: 0.8828 - loss: 0.2364 - val_accuracy: 0.7789 - val_loss: 0.6484
# Epoch 69/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.8900 - loss: 0.2427
# Test accuracy at epoch 69: 0.6949
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 114ms/step - accuracy: 0.8888 - loss: 0.2446 - val_accuracy: 0.7263 - val_loss: 0.7618
# Epoch 70/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.8610 - loss: 0.3138
# Test accuracy at epoch 70: 0.7288
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - accuracy: 0.8615 - loss: 0.3112 - val_accuracy: 0.7263 - val_loss: 0.8858
# Epoch 71/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.8944 - loss: 0.2530
# Test accuracy at epoch 71: 0.5847
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - accuracy: 0.8938 - loss: 0.2550 - val_accuracy: 0.6947 - val_loss: 0.6765
# Epoch 72/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.7990 - loss: 0.3763
# Test accuracy at epoch 72: 0.6949
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - accuracy: 0.8021 - loss: 0.3737 - val_accuracy: 0.7368 - val_loss: 0.6434
# Epoch 73/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9237 - loss: 0.1982
# Test accuracy at epoch 73: 0.6864
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.9220 - loss: 0.2009 - val_accuracy: 0.7474 - val_loss: 0.6064
# Epoch 74/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.8806 - loss: 0.2381
# Test accuracy at epoch 74: 0.7203
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - accuracy: 0.8820 - loss: 0.2369 - val_accuracy: 0.7579 - val_loss: 0.8115
# Epoch 75/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.8934 - loss: 0.2157
# Test accuracy at epoch 75: 0.6949
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 121ms/step - accuracy: 0.8945 - loss: 0.2154 - val_accuracy: 0.7263 - val_loss: 0.6901
# Epoch 76/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9271 - loss: 0.1774
# Test accuracy at epoch 76: 0.7458
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - accuracy: 0.9239 - loss: 0.1826 - val_accuracy: 0.7368 - val_loss: 0.8345
# Epoch 77/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.8312 - loss: 0.3405
# Test accuracy at epoch 77: 0.6949
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.8279 - loss: 0.3501 - val_accuracy: 0.7895 - val_loss: 0.7337
# Epoch 78/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.7781 - loss: 0.4482
# Test accuracy at epoch 78: 0.7288
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - accuracy: 0.7770 - loss: 0.4489 - val_accuracy: 0.7368 - val_loss: 0.5473
# Epoch 79/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.8429 - loss: 0.3455
# Test accuracy at epoch 79: 0.7373
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - accuracy: 0.8438 - loss: 0.3435 - val_accuracy: 0.7789 - val_loss: 0.5117
# Epoch 80/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.8884 - loss: 0.2667
# Test accuracy at epoch 80: 0.7119
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - accuracy: 0.8884 - loss: 0.2660 - val_accuracy: 0.7895 - val_loss: 0.5367
# Epoch 81/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.9199 - loss: 0.2002
# Test accuracy at epoch 81: 0.7203
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.9187 - loss: 0.2020 - val_accuracy: 0.7368 - val_loss: 0.7705
# Epoch 82/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.8998 - loss: 0.2124
# Test accuracy at epoch 82: 0.6780
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 137ms/step - accuracy: 0.9002 - loss: 0.2118 - val_accuracy: 0.7684 - val_loss: 0.8697
# Epoch 83/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.9110 - loss: 0.1767
# Test accuracy at epoch 83: 0.7288
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 131ms/step - accuracy: 0.9107 - loss: 0.1771 - val_accuracy: 0.7684 - val_loss: 0.8168
# Epoch 84/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9237 - loss: 0.1877
# Test accuracy at epoch 84: 0.7119
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 118ms/step - accuracy: 0.9228 - loss: 0.1888 - val_accuracy: 0.7895 - val_loss: 1.0155
# Epoch 85/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.9255 - loss: 0.1885
# Test accuracy at epoch 85: 0.7203
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - accuracy: 0.9249 - loss: 0.1898 - val_accuracy: 0.7368 - val_loss: 0.9873
# Epoch 86/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.9011 - loss: 0.2226
# Test accuracy at epoch 86: 0.7203
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - accuracy: 0.9010 - loss: 0.2228 - val_accuracy: 0.7579 - val_loss: 0.8364
# Epoch 87/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9196 - loss: 0.1681
# Test accuracy at epoch 87: 0.7034
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - accuracy: 0.9193 - loss: 0.1694 - val_accuracy: 0.7684 - val_loss: 1.0421
# Epoch 88/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.9208 - loss: 0.2192
# Test accuracy at epoch 88: 0.6864
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 114ms/step - accuracy: 0.9187 - loss: 0.2224 - val_accuracy: 0.7579 - val_loss: 0.6489
# Epoch 89/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.8962 - loss: 0.2121
# Test accuracy at epoch 89: 0.7119
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 108ms/step - accuracy: 0.8962 - loss: 0.2129 - val_accuracy: 0.7579 - val_loss: 0.8732
# Epoch 90/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.9449 - loss: 0.1559
# Test accuracy at epoch 90: 0.7373
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step - accuracy: 0.9445 - loss: 0.1577 - val_accuracy: 0.7895 - val_loss: 0.6527
# Epoch 91/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9442 - loss: 0.1746
# Test accuracy at epoch 91: 0.7373
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - accuracy: 0.9436 - loss: 0.1749 - val_accuracy: 0.7684 - val_loss: 0.9515
# Epoch 92/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.9259 - loss: 0.1670
# Test accuracy at epoch 92: 0.7119
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 120ms/step - accuracy: 0.9263 - loss: 0.1695 - val_accuracy: 0.8105 - val_loss: 1.2123
# Epoch 93/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.9189 - loss: 0.1534
# Test accuracy at epoch 93: 0.7627
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - accuracy: 0.9196 - loss: 0.1532 - val_accuracy: 0.7789 - val_loss: 0.9936
# Epoch 94/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.9653 - loss: 0.1193
# Test accuracy at epoch 94: 0.7458
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - accuracy: 0.9653 - loss: 0.1190 - val_accuracy: 0.7789 - val_loss: 0.9132
# Epoch 95/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9719 - loss: 0.0823
# Test accuracy at epoch 95: 0.7542
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - accuracy: 0.9720 - loss: 0.0828 - val_accuracy: 0.7579 - val_loss: 0.9598
# Epoch 96/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.9618 - loss: 0.1040
# Test accuracy at epoch 96: 0.7458
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 119ms/step - accuracy: 0.9610 - loss: 0.1050 - val_accuracy: 0.7579 - val_loss: 1.3214
# Epoch 97/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.9335 - loss: 0.1717
# Test accuracy at epoch 97: 0.7373
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.9333 - loss: 0.1725 - val_accuracy: 0.7684 - val_loss: 0.9527
# Epoch 98/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.9506 - loss: 0.1236
# Test accuracy at epoch 98: 0.7288
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - accuracy: 0.9505 - loss: 0.1237 - val_accuracy: 0.8105 - val_loss: 1.1166
# Epoch 99/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9488 - loss: 0.1033
# Test accuracy at epoch 99: 0.7373
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - accuracy: 0.9494 - loss: 0.1031 - val_accuracy: 0.8105 - val_loss: 1.0162
# Epoch 100/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.9230 - loss: 0.1709
# Test accuracy at epoch 100: 0.7034
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.9251 - loss: 0.1681 - val_accuracy: 0.8211 - val_loss: 1.1486
# Test accuracy: 0.7034
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step
# d:\Assessment\Microfluidic-Device-Data-CTC_Model\myenv\lib\site-packages\keras\src\models\functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['keras_tensor', 'keras_tensor_1']. Received: the structure of inputs=('*', '*')
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step
# Predicted cell type: ('rigid', np.float32(0.079980694), np.float32(0.92001927))
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from sklearn.metrics import roc_curve, auc
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv1D, MaxPooling1D, GlobalAveragePooling1D, Dense, LSTM, concatenate, Dropout, BatchNormalization
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical

def load_data(directory, cell_type):
    position_data = []
    velocity_data = []
    labels = []
    for filename in os.listdir(directory):
        if filename.endswith('.csv'):
            df = pd.read_csv(os.path.join(directory, filename))
            position = df[['X', 'Y', 'Z']].values
            velocity = df[['velocity_x', 'velocity_y', 'velocity_z']].values
            position_data.append(position)
            velocity_data.append(velocity)
            labels.append(cell_type)
    return position_data, velocity_data, labels

# Load PLT and WBC data
soft_position, soft_velocity, soft_labels = load_data('D:/Assessment/PINN/LSTM-Problem/NewTimeSeriesDataForCells/soft_dir', 0)
rigid_position, rigid_velocity, rigid_labels = load_data('D:/Assessment/PINN/LSTM-Problem/NewTimeSeriesDataForCells/hard_dir', 1)

# Combine data and labels
all_position_data = soft_position + rigid_position
all_velocity_data = soft_velocity + rigid_velocity
all_labels = soft_labels + rigid_labels

# Pad sequences to the same length
max_length = max(max(len(seq) for seq in all_position_data), max(len(seq) for seq in all_velocity_data))
padded_position_data = pad_sequences(all_position_data, maxlen=max_length, dtype='float32', padding='post', truncating='post')
padded_velocity_data = pad_sequences(all_velocity_data, maxlen=max_length, dtype='float32', padding='post', truncating='post')

# Normalize the data
position_scaler = StandardScaler()
velocity_scaler = StandardScaler()

normalized_position_data = np.array([position_scaler.fit_transform(seq) for seq in padded_position_data])
normalized_velocity_data = np.array([velocity_scaler.fit_transform(seq) for seq in padded_velocity_data])

# Convert labels to categorical
labels = to_categorical(all_labels)

# Split the data into training and testing sets
X_pos_train, X_pos_test, X_vel_train, X_vel_test, y_train, y_test = train_test_split(
    normalized_position_data, normalized_velocity_data, labels, test_size=0.2, random_state=42)

def create_hybrid_model(input_shape):
    # Separate inputs for position and velocity
    position_input = Input(shape=input_shape)
    velocity_input = Input(shape=input_shape)

    # Convolutions for position
    x_pos = Conv1D(64, kernel_size=3, activation='relu')(position_input)
    x_pos = BatchNormalization()(x_pos)
    x_pos = MaxPooling1D(2)(x_pos)
    x_pos = Conv1D(64, kernel_size=3, activation='relu')(x_pos)
    x_pos = BatchNormalization()(x_pos)
    x_pos = LSTM(64, return_sequences=True)(x_pos)
    x_pos = GlobalAveragePooling1D()(x_pos)

    # Convolutions for velocity
    x_vel = Conv1D(64, kernel_size=3, activation='relu')(velocity_input)
    x_vel = BatchNormalization()(x_vel)
    x_vel = MaxPooling1D(2)(x_vel)
    x_vel = Conv1D(64, kernel_size=3, activation='relu')(x_vel)
    x_vel = BatchNormalization()(x_vel)
    x_vel = LSTM(64, return_sequences=True)(x_vel)
    x_vel = GlobalAveragePooling1D()(x_vel)

    # Combine features
    combined = concatenate([x_pos, x_vel])

    # Dense layers
    x = Dense(128, activation='relu')(combined)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = Dense(64, activation='relu')(x)
    x = BatchNormalization()(x)
    output = Dense(2, activation='softmax')(x)

    # Create model
    model = Model(inputs=[position_input, velocity_input], outputs=output)
    return model

def create_all_outputs_model(model):
    return Model(inputs=model.inputs, outputs=[layer.output for layer in model.layers])

input_shape = (max_length, 3)  # 3 features for both position and velocity
model = create_hybrid_model(input_shape)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Print model summary
model.summary()

# Custom callback to track test accuracy
class TestAccuracyCallback(tf.keras.callbacks.Callback):
    def __init__(self, test_data):
        self.test_data = test_data
        self.test_accuracies = []

    def on_epoch_end(self, epoch, logs=None):
        X_pos_test, X_vel_test, y_test = self.test_data
        test_loss, test_accuracy = self.model.evaluate([X_pos_test, X_vel_test], y_test, verbose=0)
        self.test_accuracies.append(test_accuracy)
        print(f'\nTest accuracy at epoch {epoch+1}: {test_accuracy:.4f}')

# Instantiate the callback
test_accuracy_callback = TestAccuracyCallback((X_pos_test, X_vel_test, y_test))

# Train the model with the custom callback included
cnn_history = model.fit(
    [X_pos_train, X_vel_train], y_train,
    epochs=100,
    batch_size=32,
    validation_split=0.2,
    verbose=1,
    callbacks=[test_accuracy_callback]
)

all_outputs_model = create_all_outputs_model(model)

# Evaluate the model
test_loss, test_accuracy = model.evaluate([X_pos_test, X_vel_test], y_test, verbose=0)
print(f"Test accuracy: {test_accuracy:.4f}")

# Plot for Training, Validation, and Test Accuracy
plt.figure(figsize=(7, 6))

# Apply seaborn style and color palette
sns.set(style="whitegrid")
colors = sns.color_palette("muted")

plt.plot(cnn_history.history['accuracy'], label='Training Accuracy', color=colors[0], linestyle='--', linewidth=2, marker='o', markersize=5)
plt.plot(cnn_history.history['val_accuracy'], label='Validation Accuracy', color=colors[1], linestyle='--', linewidth=2, marker='s', markersize=5)
plt.plot(test_accuracy_callback.test_accuracies, label='Test Accuracy', color='green', linestyle='--', linewidth=2, marker='^', markersize=5)

plt.title('Accuracy Curve CNN+LSTM', fontsize=16, fontweight='bold')
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Accuracy', fontsize=14)
plt.legend(fontsize=12, shadow=True)
plt.grid(True, linestyle='--', alpha=0.6)

plt.tight_layout()
plt.show()

sample_pos = X_pos_test[:1]
sample_vel = X_vel_test[:1]

all_layer_outputs = all_outputs_model.predict([sample_pos, sample_vel])

# Prediction for a sample
def predict_cell_type(trajectory):
    new_position = new_trajectory[:, :3]
    new_velocity = new_trajectory[:, 3:]
    padded_position = pad_sequences([new_position], maxlen=max_length, dtype='float32', padding='post', truncating='post')
    padded_velocity = pad_sequences([new_velocity], maxlen=max_length, dtype='float32', padding='post', truncating='post')
    normalized_position = position_scaler.transform(padded_position[0])
    normalized_velocity = velocity_scaler.transform(padded_velocity[0])
    position_trajectory = normalized_position.reshape(1, max_length, 3)
    velocity_trajectory = normalized_velocity.reshape(1, max_length, 3)
    prediction = model.predict([position_trajectory, velocity_trajectory])
    cell_type = "soft" if prediction[0][0] > prediction[0][1] else "rigid"
    return cell_type, prediction[0][0], prediction[0][1]

example_csv_path = 'D:/Assessment/PINN/LSTM-Problem/NewTimeSeriesDataForCells/hard_dir/output_0.0 (1)_split_1.csv'
new_trajectory = pd.read_csv(example_csv_path)[['X', 'Y', 'Z','velocity_x', 'velocity_y', 'velocity_z']].values
predicted_cell_type_1 = predict_cell_type(new_trajectory)
print(f"Predicted cell type: {predicted_cell_type_1}")

# Apply seaborn style and color palette
sns.set(style="whitegrid")
colors = sns.color_palette("muted")

# Compute ROC curve and ROC area for the model
y_pred = model.predict([X_pos_test, X_vel_test])
fpr, tpr, _ = roc_curve(y_test[:, 1], y_pred[:, 1])
roc_auc = auc(fpr, tpr)

# Plot for ROC curve
plt.figure(figsize=(7, 6))

plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})', marker='o', markersize=5)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=14)
plt.ylabel('True Positive Rate', fontsize=14)
plt.title('Receiver Operating Characteristic (ROC) Curve (CNN+LSTM)', fontsize=16, fontweight='bold')
plt.legend(loc="lower right", fontsize=12, shadow=True)
plt.grid(True, linestyle='--', alpha=0.6)

plt.tight_layout()
plt.show()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 431, 3)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_3       │ (None, 431, 3)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_4 (Conv1D)   │ (None, 429, 64)   │        640 │ input_layer_2[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_6 (Conv1D)   │ (None, 429, 64)   │        640 │ input_layer_3[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 429, 64)   │        256 │ conv1d_4[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 429, 64)   │        256 │ conv1d_6[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_2     │ (None, 214, 64)   │          0 │ batch_normalizat… │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_3     │ (None, 214, 64)   │          0 │ batch_normalizat… │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_5 (Conv1D)   │ (None, 212, 64)   │     12,352 │ max_pooling1d_2[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_7 (Conv1D)   │ (None, 212, 64)   │     12,352 │ max_pooling1d_3[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 212, 64)   │        256 │ conv1d_5[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 212, 64)   │        256 │ conv1d_7[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_2 (LSTM)       │ (None, 212, 64)   │     33,024 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_3 (LSTM)       │ (None, 212, 64)   │     33,024 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 64)        │          0 │ lstm_2[0][0]      │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 64)        │          0 │ lstm_3[0][0]      │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 128)       │          0 │ global_average_p… │
# │ (Concatenate)       │                   │            │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 128)       │     16,512 │ concatenate_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128)       │        512 │ dense_3[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 128)       │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 64)        │      8,256 │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64)        │        256 │ dense_4[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 2)         │        130 │ batch_normalizat… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 118,722 (463.76 KB)
#  Trainable params: 117,826 (460.26 KB)
#  Non-trainable params: 896 (3.50 KB)
# Epoch 1/100
# d:\Assessment\Microfluidic-Device-Data-CTC_Model\myenv\lib\site-packages\keras\src\models\functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['keras_tensor_17', 'keras_tensor_18']. Received: the structure of inputs=('*', '*')
#   warnings.warn(
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.5157 - loss: 0.9318
# Test accuracy at epoch 1: 0.5763
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 176ms/step - accuracy: 0.5170 - loss: 0.9290 - val_accuracy: 0.5368 - val_loss: 0.6915
# Epoch 2/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.5956 - loss: 0.7760
# Test accuracy at epoch 2: 0.5763
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 128ms/step - accuracy: 0.5946 - loss: 0.7760 - val_accuracy: 0.5368 - val_loss: 0.6952
# Epoch 3/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.5382 - loss: 0.8149
# Test accuracy at epoch 3: 0.5763
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 122ms/step - accuracy: 0.5417 - loss: 0.8108 - val_accuracy: 0.5368 - val_loss: 0.6978
# Epoch 4/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.6168 - loss: 0.6884
# Test accuracy at epoch 4: 0.5763
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 124ms/step - accuracy: 0.6181 - loss: 0.6878 - val_accuracy: 0.5368 - val_loss: 0.6989
# Epoch 5/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.6304 - loss: 0.6336
# Test accuracy at epoch 5: 0.5763
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 124ms/step - accuracy: 0.6321 - loss: 0.6339 - val_accuracy: 0.5368 - val_loss: 0.6980
# Epoch 6/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.6308 - loss: 0.6738
# Test accuracy at epoch 6: 0.5763
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 133ms/step - accuracy: 0.6316 - loss: 0.6716 - val_accuracy: 0.5368 - val_loss: 0.6982
# Epoch 7/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.6984 - loss: 0.5811
# Test accuracy at epoch 7: 0.5763
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 124ms/step - accuracy: 0.6977 - loss: 0.5827 - val_accuracy: 0.5368 - val_loss: 0.6927
# Epoch 8/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.6915 - loss: 0.5482
# Test accuracy at epoch 8: 0.5763
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 132ms/step - accuracy: 0.6910 - loss: 0.5498 - val_accuracy: 0.5368 - val_loss: 0.6894
# Epoch 9/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.7440 - loss: 0.5336
# Test accuracy at epoch 9: 0.5763
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 129ms/step - accuracy: 0.7445 - loss: 0.5335 - val_accuracy: 0.5368 - val_loss: 0.6898
# Epoch 10/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.7194 - loss: 0.5366
# Test accuracy at epoch 10: 0.5763
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 133ms/step - accuracy: 0.7203 - loss: 0.5348 - val_accuracy: 0.5368 - val_loss: 0.6891
# Epoch 11/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.7710 - loss: 0.4832
# Test accuracy at epoch 11: 0.5847
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 122ms/step - accuracy: 0.7692 - loss: 0.4852 - val_accuracy: 0.5579 - val_loss: 0.6799
# Epoch 12/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.7957 - loss: 0.4578
# Test accuracy at epoch 12: 0.5763
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 122ms/step - accuracy: 0.7924 - loss: 0.4615 - val_accuracy: 0.6105 - val_loss: 0.6722
# Epoch 13/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.8058 - loss: 0.4163
# Test accuracy at epoch 13: 0.5593
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 123ms/step - accuracy: 0.8065 - loss: 0.4154 - val_accuracy: 0.6000 - val_loss: 0.6718
# Epoch 14/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.7762 - loss: 0.4213
# Test accuracy at epoch 14: 0.5508
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 124ms/step - accuracy: 0.7773 - loss: 0.4205 - val_accuracy: 0.6421 - val_loss: 0.6568
# Epoch 15/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.8287 - loss: 0.3976
# Test accuracy at epoch 15: 0.5932
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 161ms/step - accuracy: 0.8268 - loss: 0.3980 - val_accuracy: 0.5789 - val_loss: 0.6708
# Epoch 16/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.7818 - loss: 0.4041
# Test accuracy at epoch 16: 0.5678
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 128ms/step - accuracy: 0.7833 - loss: 0.4024 - val_accuracy: 0.5684 - val_loss: 0.6829
# Epoch 17/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.8563 - loss: 0.3219
# Test accuracy at epoch 17: 0.5932
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 122ms/step - accuracy: 0.8559 - loss: 0.3213 - val_accuracy: 0.5579 - val_loss: 0.6887
# Epoch 18/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.8627 - loss: 0.3085
# Test accuracy at epoch 18: 0.5847
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 123ms/step - accuracy: 0.8614 - loss: 0.3096 - val_accuracy: 0.5368 - val_loss: 0.7791
# Epoch 19/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.8678 - loss: 0.2925
# Test accuracy at epoch 19: 0.5932
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 122ms/step - accuracy: 0.8663 - loss: 0.2944 - val_accuracy: 0.5684 - val_loss: 0.7270
# Epoch 20/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.8479 - loss: 0.2887
# Test accuracy at epoch 20: 0.6102
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 171ms/step - accuracy: 0.8490 - loss: 0.2884 - val_accuracy: 0.5789 - val_loss: 0.6818
# Epoch 21/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.8636 - loss: 0.2811
# Test accuracy at epoch 21: 0.6271
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 138ms/step - accuracy: 0.8651 - loss: 0.2805 - val_accuracy: 0.6211 - val_loss: 0.6224
# Epoch 22/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.8964 - loss: 0.2443
# Test accuracy at epoch 22: 0.6017
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 175ms/step - accuracy: 0.8943 - loss: 0.2475 - val_accuracy: 0.6526 - val_loss: 0.6468
# Epoch 23/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.8454 - loss: 0.3296
# Test accuracy at epoch 23: 0.6271
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 137ms/step - accuracy: 0.8465 - loss: 0.3273 - val_accuracy: 0.5684 - val_loss: 0.8596
# Epoch 24/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.8534 - loss: 0.3215
# Test accuracy at epoch 24: 0.6017
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 141ms/step - accuracy: 0.8537 - loss: 0.3215 - val_accuracy: 0.5684 - val_loss: 0.9039
# Epoch 25/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9183 - loss: 0.2145
# Test accuracy at epoch 25: 0.6102
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 183ms/step - accuracy: 0.9167 - loss: 0.2160 - val_accuracy: 0.6105 - val_loss: 0.8053
# Epoch 26/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.9199 - loss: 0.2000
# Test accuracy at epoch 26: 0.6186
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.9191 - loss: 0.2007 - val_accuracy: 0.6211 - val_loss: 0.8072
# Epoch 27/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.8901 - loss: 0.2364
# Test accuracy at epoch 27: 0.6525
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 203ms/step - accuracy: 0.8913 - loss: 0.2346 - val_accuracy: 0.6842 - val_loss: 0.6484
# Epoch 28/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.9557 - loss: 0.1402
# Test accuracy at epoch 28: 0.6186
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 138ms/step - accuracy: 0.9555 - loss: 0.1402 - val_accuracy: 0.6105 - val_loss: 1.0290
# Epoch 29/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9472 - loss: 0.1527
# Test accuracy at epoch 29: 0.6525
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 161ms/step - accuracy: 0.9462 - loss: 0.1542 - val_accuracy: 0.6632 - val_loss: 0.7933
# Epoch 30/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.8983 - loss: 0.2245
# Test accuracy at epoch 30: 0.6186
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.8992 - loss: 0.2248 - val_accuracy: 0.6632 - val_loss: 0.6655
# Epoch 31/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9121 - loss: 0.1855
# Test accuracy at epoch 31: 0.6102
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 0.9134 - loss: 0.1847 - val_accuracy: 0.6105 - val_loss: 1.0257
# Epoch 32/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.9296 - loss: 0.1524
# Test accuracy at epoch 32: 0.7119
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 168ms/step - accuracy: 0.9303 - loss: 0.1522 - val_accuracy: 0.7474 - val_loss: 0.5354
# Epoch 33/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.9323 - loss: 0.1550
# Test accuracy at epoch 33: 0.6864
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 147ms/step - accuracy: 0.9328 - loss: 0.1547 - val_accuracy: 0.6632 - val_loss: 0.7638
# Epoch 34/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.9732 - loss: 0.0881
# Test accuracy at epoch 34: 0.6864
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 163ms/step - accuracy: 0.9712 - loss: 0.0910 - val_accuracy: 0.6737 - val_loss: 0.7461
# Epoch 35/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.9769 - loss: 0.0699
# Test accuracy at epoch 35: 0.7373
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 154ms/step - accuracy: 0.9773 - loss: 0.0694 - val_accuracy: 0.7579 - val_loss: 0.5690
# Epoch 36/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.9883 - loss: 0.0574
# Test accuracy at epoch 36: 0.7373
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 141ms/step - accuracy: 0.9880 - loss: 0.0575 - val_accuracy: 0.7474 - val_loss: 0.6164
# Epoch 37/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9588 - loss: 0.0891
# Test accuracy at epoch 37: 0.5593
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 142ms/step - accuracy: 0.9591 - loss: 0.0893 - val_accuracy: 0.5789 - val_loss: 1.3775
# Epoch 38/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.9361 - loss: 0.1133
# Test accuracy at epoch 38: 0.7458
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 155ms/step - accuracy: 0.9379 - loss: 0.1114 - val_accuracy: 0.7474 - val_loss: 0.6395
# Epoch 39/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.9660 - loss: 0.1113
# Test accuracy at epoch 39: 0.7881
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 178ms/step - accuracy: 0.9657 - loss: 0.1112 - val_accuracy: 0.7895 - val_loss: 0.7085
# Epoch 40/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.9731 - loss: 0.0895
# Test accuracy at epoch 40: 0.7034
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 166ms/step - accuracy: 0.9729 - loss: 0.0889 - val_accuracy: 0.7684 - val_loss: 0.5875
# Epoch 41/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.9659 - loss: 0.0912
# Test accuracy at epoch 41: 0.6102
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 168ms/step - accuracy: 0.9665 - loss: 0.0899 - val_accuracy: 0.6421 - val_loss: 1.1092
# Epoch 42/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.9538 - loss: 0.1139
# Test accuracy at epoch 42: 0.5593
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 152ms/step - accuracy: 0.9545 - loss: 0.1117 - val_accuracy: 0.6526 - val_loss: 1.1899
# Epoch 43/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.9741 - loss: 0.0571
# Test accuracy at epoch 43: 0.7458
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 148ms/step - accuracy: 0.9742 - loss: 0.0570 - val_accuracy: 0.7789 - val_loss: 0.6447
# Epoch 44/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.9848 - loss: 0.0418
# Test accuracy at epoch 44: 0.7542
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 136ms/step - accuracy: 0.9851 - loss: 0.0411 - val_accuracy: 0.8000 - val_loss: 0.5545
# Epoch 45/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.9973 - loss: 0.0278
# Test accuracy at epoch 45: 0.7373
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 160ms/step - accuracy: 0.9973 - loss: 0.0277 - val_accuracy: 0.8211 - val_loss: 0.5710
# Epoch 46/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9995 - loss: 0.0134
# Test accuracy at epoch 46: 0.7627
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 129ms/step - accuracy: 0.9994 - loss: 0.0136 - val_accuracy: 0.7789 - val_loss: 0.6216
# Epoch 47/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.9924 - loss: 0.0372
# Test accuracy at epoch 47: 0.7712
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 137ms/step - accuracy: 0.9926 - loss: 0.0365 - val_accuracy: 0.7895 - val_loss: 0.6098
# Epoch 48/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.9995 - loss: 0.0113
# Test accuracy at epoch 48: 0.7373
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.9994 - loss: 0.0117 - val_accuracy: 0.8316 - val_loss: 0.7230
# Epoch 49/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 1.0000 - loss: 0.0092
# Test accuracy at epoch 49: 0.6949
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 149ms/step - accuracy: 1.0000 - loss: 0.0091 - val_accuracy: 0.8211 - val_loss: 0.7424
# Epoch 50/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9990 - loss: 0.0080
# Test accuracy at epoch 50: 0.7373
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 152ms/step - accuracy: 0.9989 - loss: 0.0082 - val_accuracy: 0.7895 - val_loss: 0.6978
# Epoch 51/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 1.0000 - loss: 0.0167
# Test accuracy at epoch 51: 0.7712
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 144ms/step - accuracy: 1.0000 - loss: 0.0164 - val_accuracy: 0.7684 - val_loss: 0.7486
# Epoch 52/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.9998 - loss: 0.0107
# Test accuracy at epoch 52: 0.7881
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 140ms/step - accuracy: 0.9996 - loss: 0.0110 - val_accuracy: 0.8000 - val_loss: 0.6126
# Epoch 53/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.9872 - loss: 0.0476
# Test accuracy at epoch 53: 0.7458
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 155ms/step - accuracy: 0.9864 - loss: 0.0497 - val_accuracy: 0.7895 - val_loss: 0.7895
# Epoch 54/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.9206 - loss: 0.2244
# Test accuracy at epoch 54: 0.6271
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 145ms/step - accuracy: 0.9216 - loss: 0.2210 - val_accuracy: 0.6105 - val_loss: 1.5732
# Epoch 55/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8678 - loss: 0.3435
# Test accuracy at epoch 55: 0.5932
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 136ms/step - accuracy: 0.8661 - loss: 0.3472 - val_accuracy: 0.6211 - val_loss: 2.0692
# Epoch 56/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.8761 - loss: 0.2714
# Test accuracy at epoch 56: 0.7458
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 126ms/step - accuracy: 0.8779 - loss: 0.2685 - val_accuracy: 0.8000 - val_loss: 0.5391
# Epoch 57/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.9424 - loss: 0.1616
# Test accuracy at epoch 57: 0.7542
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 162ms/step - accuracy: 0.9429 - loss: 0.1604 - val_accuracy: 0.7263 - val_loss: 0.6881
# Epoch 58/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9404 - loss: 0.1338
# Test accuracy at epoch 58: 0.6949
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 132ms/step - accuracy: 0.9415 - loss: 0.1316 - val_accuracy: 0.7789 - val_loss: 0.8144
# Epoch 59/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.9796 - loss: 0.0588
# Test accuracy at epoch 59: 0.6949
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 133ms/step - accuracy: 0.9799 - loss: 0.0582 - val_accuracy: 0.7263 - val_loss: 0.9949
# Epoch 60/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9824 - loss: 0.0459
# Test accuracy at epoch 60: 0.7119
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 136ms/step - accuracy: 0.9823 - loss: 0.0461 - val_accuracy: 0.6947 - val_loss: 1.0943
# Epoch 61/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.9919 - loss: 0.0223
# Test accuracy at epoch 61: 0.7797
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 145ms/step - accuracy: 0.9923 - loss: 0.0219 - val_accuracy: 0.7684 - val_loss: 0.8581
# Epoch 62/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 1.0000 - loss: 0.0133
# Test accuracy at epoch 62: 0.7712
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 140ms/step - accuracy: 1.0000 - loss: 0.0134 - val_accuracy: 0.8000 - val_loss: 0.8818
# Epoch 63/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9886 - loss: 0.0407
# Test accuracy at epoch 63: 0.8051
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 139ms/step - accuracy: 0.9891 - loss: 0.0395 - val_accuracy: 0.8105 - val_loss: 0.7950
# Epoch 64/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 1.0000 - loss: 0.0104
# Test accuracy at epoch 64: 0.7966
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 131ms/step - accuracy: 1.0000 - loss: 0.0105 - val_accuracy: 0.8000 - val_loss: 0.7638
# Epoch 65/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 1.0000 - loss: 0.0075
# Test accuracy at epoch 65: 0.7712
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 130ms/step - accuracy: 1.0000 - loss: 0.0077 - val_accuracy: 0.8000 - val_loss: 0.8415
# Epoch 66/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9993 - loss: 0.0113
# Test accuracy at epoch 66: 0.7881
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 127ms/step - accuracy: 0.9991 - loss: 0.0115 - val_accuracy: 0.8105 - val_loss: 0.7826
# Epoch 67/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9998 - loss: 0.0053
# Test accuracy at epoch 67: 0.7881
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 142ms/step - accuracy: 0.9996 - loss: 0.0059 - val_accuracy: 0.8105 - val_loss: 0.7853
# Epoch 68/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.9964 - loss: 0.0136
# Test accuracy at epoch 68: 0.7288
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 171ms/step - accuracy: 0.9960 - loss: 0.0145 - val_accuracy: 0.7474 - val_loss: 1.0442
# Epoch 69/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9958 - loss: 0.0118
# Test accuracy at epoch 69: 0.7712
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 139ms/step - accuracy: 0.9959 - loss: 0.0116 - val_accuracy: 0.8000 - val_loss: 0.7661
# Epoch 70/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 1.0000 - loss: 0.0122
# Test accuracy at epoch 70: 0.7542
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 136ms/step - accuracy: 1.0000 - loss: 0.0122 - val_accuracy: 0.7895 - val_loss: 0.6849
# Epoch 71/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.9998 - loss: 0.0054
# Test accuracy at epoch 71: 0.7288
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 144ms/step - accuracy: 0.9996 - loss: 0.0058 - val_accuracy: 0.8000 - val_loss: 0.7922
# Epoch 72/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.9935 - loss: 0.0207
# Test accuracy at epoch 72: 0.7119
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 161ms/step - accuracy: 0.9936 - loss: 0.0212 - val_accuracy: 0.6526 - val_loss: 1.6112
# Epoch 73/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9984 - loss: 0.0152
# Test accuracy at epoch 73: 0.7712
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 144ms/step - accuracy: 0.9979 - loss: 0.0160 - val_accuracy: 0.7789 - val_loss: 0.8732
# Epoch 74/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.9891 - loss: 0.0224
# Test accuracy at epoch 74: 0.6864
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 143ms/step - accuracy: 0.9887 - loss: 0.0230 - val_accuracy: 0.7368 - val_loss: 1.0612
# Epoch 75/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9620 - loss: 0.1158
# Test accuracy at epoch 75: 0.7288
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 140ms/step - accuracy: 0.9623 - loss: 0.1160 - val_accuracy: 0.7474 - val_loss: 0.8712
# Epoch 76/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.9634 - loss: 0.0820
# Test accuracy at epoch 76: 0.7712
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 129ms/step - accuracy: 0.9638 - loss: 0.0807 - val_accuracy: 0.7684 - val_loss: 0.9035
# Epoch 77/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.9664 - loss: 0.0804
# Test accuracy at epoch 77: 0.7373
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 151ms/step - accuracy: 0.9673 - loss: 0.0786 - val_accuracy: 0.7263 - val_loss: 1.0526
# Epoch 78/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.9774 - loss: 0.0675
# Test accuracy at epoch 78: 0.5847
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 131ms/step - accuracy: 0.9777 - loss: 0.0680 - val_accuracy: 0.6526 - val_loss: 1.5041
# Epoch 79/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.9822 - loss: 0.0470
# Test accuracy at epoch 79: 0.7542
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 135ms/step - accuracy: 0.9825 - loss: 0.0462 - val_accuracy: 0.7368 - val_loss: 0.7658
# Epoch 80/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.9839 - loss: 0.0416
# Test accuracy at epoch 80: 0.7966
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9837 - loss: 0.0418 - val_accuracy: 0.7789 - val_loss: 0.6439
# Epoch 81/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.9881 - loss: 0.0336
# Test accuracy at epoch 81: 0.6610
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 128ms/step - accuracy: 0.9884 - loss: 0.0331 - val_accuracy: 0.6526 - val_loss: 1.5364
# Epoch 82/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.9963 - loss: 0.0151
# Test accuracy at epoch 82: 0.7712
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 197ms/step - accuracy: 0.9958 - loss: 0.0162 - val_accuracy: 0.7579 - val_loss: 0.8604
# Epoch 83/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.9966 - loss: 0.0160
# Test accuracy at epoch 83: 0.7288
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 167ms/step - accuracy: 0.9964 - loss: 0.0163 - val_accuracy: 0.7579 - val_loss: 0.8008
# Epoch 84/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.9979 - loss: 0.0187
# Test accuracy at epoch 84: 0.7288
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 143ms/step - accuracy: 0.9978 - loss: 0.0186 - val_accuracy: 0.7263 - val_loss: 0.9553
# Epoch 85/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 1.0000 - loss: 0.0064
# Test accuracy at epoch 85: 0.8051
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 180ms/step - accuracy: 1.0000 - loss: 0.0063 - val_accuracy: 0.7895 - val_loss: 0.6988
# Epoch 86/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.9944 - loss: 0.0177
# Test accuracy at epoch 86: 0.7288
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 145ms/step - accuracy: 0.9940 - loss: 0.0184 - val_accuracy: 0.8105 - val_loss: 0.7641
# Epoch 87/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.9973 - loss: 0.0089
# Test accuracy at epoch 87: 0.7712
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 159ms/step - accuracy: 0.9973 - loss: 0.0090 - val_accuracy: 0.7684 - val_loss: 1.0783
# Epoch 88/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.9838 - loss: 0.0407
# Test accuracy at epoch 88: 0.7627
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 160ms/step - accuracy: 0.9847 - loss: 0.0390 - val_accuracy: 0.7579 - val_loss: 1.3404
# Epoch 89/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 1.0000 - loss: 0.0063
# Test accuracy at epoch 89: 0.7712
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 169ms/step - accuracy: 1.0000 - loss: 0.0064 - val_accuracy: 0.8316 - val_loss: 0.7393
# Epoch 90/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 1.0000 - loss: 0.0042
# Test accuracy at epoch 90: 0.7966
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 153ms/step - accuracy: 1.0000 - loss: 0.0043 - val_accuracy: 0.8000 - val_loss: 0.9356
# Epoch 91/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 1.0000 - loss: 0.0050
# Test accuracy at epoch 91: 0.7712
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 166ms/step - accuracy: 1.0000 - loss: 0.0051 - val_accuracy: 0.8316 - val_loss: 0.8697
# Epoch 92/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 1.0000 - loss: 0.0047
# Test accuracy at epoch 92: 0.7881
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 161ms/step - accuracy: 1.0000 - loss: 0.0047 - val_accuracy: 0.8316 - val_loss: 0.9201
# Epoch 93/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 1.0000 - loss: 0.0043
# Test accuracy at epoch 93: 0.7797
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 138ms/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 0.8211 - val_loss: 0.8926
# Epoch 94/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 1.0000 - loss: 0.0011
# Test accuracy at epoch 94: 0.7881
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 148ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.8316 - val_loss: 0.9469
# Epoch 95/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 1.0000 - loss: 9.6294e-04
# Test accuracy at epoch 95: 0.7881
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 152ms/step - accuracy: 1.0000 - loss: 9.9901e-04 - val_accuracy: 0.8211 - val_loss: 0.9231
# Epoch 96/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 1.0000 - loss: 0.0013
# Test accuracy at epoch 96: 0.7881
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 138ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.8211 - val_loss: 0.9210
# Epoch 97/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 1.0000 - loss: 0.0014
# Test accuracy at epoch 97: 0.7797
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 131ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.8211 - val_loss: 0.9592
# Epoch 98/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 1.0000 - loss: 0.0029
# Test accuracy at epoch 98: 0.7712
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 131ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.8316 - val_loss: 0.8761
# Epoch 99/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 1.0000 - loss: 0.0019
# Test accuracy at epoch 99: 0.7712
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 134ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.8316 - val_loss: 0.8643
# Epoch 100/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 1.0000 - loss: 0.0016
# Test accuracy at epoch 100: 0.7627
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 128ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.8316 - val_loss: 0.8811
# Test accuracy: 0.7627
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 458ms/step
# d:\Assessment\Microfluidic-Device-Data-CTC_Model\myenv\lib\site-packages\keras\src\models\functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['keras_tensor_17', 'keras_tensor_18']. Received: the structure of inputs=('*', '*')
#   warnings.warn(
# WARNING:tensorflow:5 out of the last 8 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000002319F15A560> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 705ms/step
# Predicted cell type: ('rigid', np.float32(2.0492219e-16), np.float32(1.0))
# WARNING:tensorflow:6 out of the last 9 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000002319F15A560> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step
